# %%
import pandas as pd
import math
from geopy import distance
import networkx as nx
import itertools

# NO LOOPS!!! CODE BREAKS IF THERE ARE LOOPS!!

ROOT_DIR = '/Users/alexanderguo/Google Drive/MIT/junior/sem2/projects/metroworld/'
pd.options.display.max_rows = 999

# EDIT FOR DIFFERNET CONSTANTS
MAX_SPEED_KMH = 1200 # kmh
ACCELERATION = 3 # m/s2. CONSTANT ACCELERATION ONLY. DE_ACCELERATION MUST BE SAME (otherwise math too complicated)
TIME_AT_STATION_M = 5 # minutes
TRANSFER_TIME_1_M = 30 # minutes
TRANSFER_TIME_2_M = 240 # minutes
EXPRESS_POP_CUTOFF = 2000000 # population needed for an express station



MAX_SPEED = MAX_SPEED_KMH/3.6 # m/s2
ACC_TIME = MAX_SPEED/ACCELERATION # s
ACC_DISTANCE = ACC_TIME * MAX_SPEED / 2 # d = 1/2 at^2
TIME_AT_STATION = TIME_AT_STATION_M * 60 # s
TRANSFER_TIME_1 = TRANSFER_TIME_1_M * 60 # s
TRANSFER_TIME_2 = TRANSFER_TIME_2_M * 60 # s

with open(ROOT_DIR + 'metro_data.txt', 'r') as f:
    lines_raw = [a.strip().replace(':', '') for a in f.readlines()]

# %%
line_dict = {}
station_set = set()
next_is_stations_mainline = False
next_is_stations_branch = False
current_line_name = ''
current_branch_name = ''

# add to line_dict and station_set
for text_line in lines_raw:
    if text_line.split(' ')[-1] == 'LINE':
        current_line_name = text_line.split(' ')[0]
        line_dict[current_line_name] = None
        next_is_stations_mainline = True
    elif next_is_stations_mainline == True:
        line_dict[current_line_name] = text_line.split(',')
        next_is_stations_mainline = False
        station_set = station_set.union(set(text_line.split(',')))
    elif text_line.split(' ')[0] == 'BRANCH':
        current_branch_name = ' '.join(text_line.split(' ')[3:]) + '_' + current_line_name + '_' + text_line.split(' ')[1]
        line_dict[current_branch_name] = None
        next_is_stations_branch = True
    elif next_is_stations_branch == True:
        line_dict[current_branch_name] = text_line.split(',')
        next_is_stations_branch = False
        station_set = station_set.union(set(text_line.split(',')))

line_totals = {}
for line in line_dict:
    if '_' not in line: # main line
        line_totals[line] = line_totals[line] + len(line_dict[line]) if line in line_totals else len(line_dict[line])
    else:
        actual_line = line.split('_')[1]
        line_totals[actual_line] = line_totals[actual_line] + len(line_dict[line]) if actual_line in line_totals else len(line_dict[line])

# line_totals
station_set
# Out:
# {'Abidjan',
#  'Abu Dhabi',
#  'Abuja',
#  'Accra',
#  'Addis Ababa',
#  'Ahmadabad',
#  'Alexandria',
#  'Algiers',
#  'Almaty',
#  'Amman',
#  'Amsterdam',
#  'Anchorage',
#  'Ankara',
#  'Antananarivo',
#  'Ashgabat',
#  'Asmara',
#  'Asuncion',
#  'Athens',
#  'Atlanta',
#  'Auckland',
#  'Baghdad',
#  'Baku',
#  'Bali',
#  'Bamako',
#  'Bandar Seri Begawan',
#  'Bangalore',
#  'Bangkok',
#  'Bangui',
#  'Banjul',
#  'Barcelona',
#  'Basse-Terre',
#  'Bata',
#  'Beijing',
#  'Beirut',
#  'Belgrade',
#  'Belize City',
#  'Belo Horizonte',
#  'Berlin',
#  'Bishkek',
#  'Bissau',
#  'Bogota',
#  'Boston',
#  'Brasilia',
#  'Bratislava',
#  'Brazzaville',
#  'Bridgetown',
#  'Brisbane',
#  'Brussels',
#  'Bucharest',
#  'Budapest',
#  'Buenos Aires',
#  'Bujumbura',
#  'Busan',
#  'Cairo',
#  'Calgary',
#  'Cape Town',
#  'Caracas',
#  'Casablanca',
#  'Cayenne',
#  'Chengdu',
#  'Chennai',
#  'Chicago',
#  'Chisinau',
#  'Chittagong',
#  'Chongqing',
#  'Christchurch',
#  'Colombo',
#  'Conakry',
#  'Copenhagen',
#  'Cotonou',
#  'Dakar',
#  'Dalian',
#  'Dallas',
#  'Damascus',
#  'Dar es Salaam',
#  'Davao',
#  'Delhi',
#  'Denver',
#  'Dhaka',
#  'Dili',
#  'Djibouti',
#  'Doha',
#  'Douala',
#  'Dubai',
#  'Dublin',
#  'Dushanbe',
#  'Fort-de-France',
#  'Fortaleza',
#  'Frankfurt',
#  'Freetown',
#  'Fukuoka',
#  'Gaborone',
#  'Georgetown',
#  'Glasgow',
#  'Guadalajara',
#  'Guangzhou',
#  'Guatemala City',
#  'Hangzhou',
#  'Hanoi',
#  'Harare',
#  'Harbin',
#  'Havana',
#  'Helsinki',
#  'Ho Chi Minh City',
#  'Hong Kong',
#  'Honiara',
#  'Honolulu',
#  'Houston',
#  'Hyderabad',
#  'Irkutsk',
#  'Islamabad',
#  'Istanbul',
#  'Jakarta',
#  'Jeddah',
#  'Jerusalem',
#  'Jinan',
#  'Johannesburg',
#  'Juba',
#  'Kabul',
#  'Kampala',
#  'Kano',
#  'Karachi',
#  'Kathmandu',
#  'Kazan',
#  'Khabarovsk',
#  'Khartoum',
#  'Kigali',
#  'Kingston',
#  'Kinshasa',
#  'Kolkata',
#  'Krasnoyarsk',
#  'Kuala Lumpur',
#  'Kuwait City',
#  'Kyiv',
#  'La Paz',
#  'Laayoune',
#  'Lagos',
#  'Lahore',
#  'Las Vegas',
#  'Libreville',
#  'Lilongwe',
#  'Lima',
#  'Lisbon',
#  'Ljubljana',
#  'Lome',
#  'London',
#  'Los Angeles',
#  'Luanda',
#  'Lubumbashi',
#  'Lucknow',
#  'Lusaka',
#  'Lyon',
#  'Macau',
#  'Madrid',
#  'Male',
#  'Managua',
#  'Manama',
#  'Mandalay',
#  'Manila',
#  'Maputo',
#  'Maseru',
#  'Mashhad',
#  'Mbabane',
#  'Medan',
#  'Medellin',
#  'Melbourne',
#  'Mexico City',
#  'Miami',
#  'Milan',
#  'Minsk',
#  'Mogadishu',
#  'Mombasa',
#  'Monaco',
#  'Monrovia',
#  'Monterrey',
#  'Montevideo',
#  'Montreal',
#  'Moroni',
#  'Moscow',
#  'Mumbai',
#  'Muscat',
#  'Mwanza',
#  "N'Djamena",
#  'Nagpur',
#  'Nairobi',
#  'Nanjing',
#  'Nassau',
#  'New York City',
#  'Niamey',
#  'Nouakchott',
#  'Noumea',
#  'Novosibirsk',
#  'Osaka',
#  'Oslo',
#  'Ottawa',
#  'Ouagadougou',
#  'Panama City',
#  'Paramaribo',
#  'Paris',
#  'Perth',
#  'Phnom Penh',
#  'Phoenix',
#  'Phuket',
#  'Port Louis',
#  'Port Moresby',
#  'Port of Spain',
#  'Port-au-Prince',
#  'Prague',
#  'Pune',
#  'Pyongyang',
#  'Quito',
#  'Reykjavik',
#  'Riga',
#  'Rio de Janeiro',
#  'Riyadh',
#  'Rome',
#  'Saint Petersburg',
#  'Saint-Denis',
#  'Salvador',
#  'San Francisco',
#  'San Jose',
#  'San Juan',
#  'San Salvador',
#  'Sanaa',
#  'Santa Cruz de la Sierra',
#  'Santiago',
#  'Santo Domingo',
#  'Sanya',
#  'Sao Paulo',
#  'Sapporo',
#  'Sarajevo',
#  'Seattle',
#  'Seoul',
#  'Sevastopol',
#  'Shanghai',
#  'Shenyang',
#  'Shenzhen',
#  'Singapore',
#  'Skopje',
#  'Sofia',
#  'Stockholm',
#  'Surabaya',
#  'Surat',
#  'Suva',
#  'Sydney',
#  'Taipei',
#  'Tallinn',
#  'Tashkent',
#  'Tbilisi',
#  'Tegucigalpa',
#  'Tehran',
#  'Thimphu',
#  'Tianjin',
#  'Tirana',
#  'Tokyo',
#  'Toronto',
#  'Tripoli',
#  'Tunis',
#  'Ulaanbaatar',
#  'Urumqi',
#  'Vancouver',
#  'Vienna',
#  'Vientiane',
#  'Vilnius',
#  'Vladivostok',
#  'Warsaw',
#  'Washington D.C.',
#  'Windhoek',
#  'Winnipeg',
#  'Wuhan',
#  "Xi'an",
#  'Yangon',
#  'Yaounde',
#  'Yekaterinburg',
#  'Yerevan',
#  'Zagreb',
#  'Zurich'}

# %%
station_df = pd.DataFrame(sorted(list(station_set)), columns=['station'])

country_map = pd.read_csv(ROOT_DIR + 'iso_3166_country_mapping.csv')[['alpha-3', 'name', 'region', 'sub-region']]
city_map = pd.read_csv(ROOT_DIR + 'worldcities.csv')[['city_ascii', 'lat', 'lng', 'iso3', 'population']]
# station_df

# too many duplicates otherwise
city_map_small = city_map[(city_map['population'] > 60000) | (city_map['city_ascii'].isin(['Basse-Terre', 'Banjul', 'Monaco', 'Santa Cruz de la Sierra']))]

station_df = station_df.merge(city_map_small, left_on='station', right_on='city_ascii', how='left').drop(columns=['city_ascii'])
station_df = station_df.merge(country_map, left_on='iso3', right_on='alpha-3', how='left').drop(columns=['alpha-3'])

station_df = station_df.rename(columns={'iso3': 'country_code', 'name': 'country_territory', 'lng': 'long', 'sub-region': 'sub_region'})

print('Total stations:', station_df.shape[0])
print('Stations in urban areas with pop >5m:', station_df[station_df['population'] > 5000000].shape[0])
print('Stations in urban areas with pop >3m:', station_df[station_df['population'] > 3000000].shape[0])
print('Stations in urban areas with pop >2m:', station_df[station_df['population'] > 2000000].shape[0])
print('Stations in urban areas with pop >1m:', station_df[station_df['population'] > 1000000].shape[0])
print('Stations in urban areas with pop >500k:', station_df[station_df['population'] > 500000].shape[0])
print('Stations in urban areas with pop >100k:', station_df[station_df['population'] > 100000].shape[0])
print('Stations in urban areas with pop >50k:', station_df[station_df['population'] > 50000].shape[0])
print('Total population in urban area of stations:', station_df['population'].sum())

station_df
# Out:
# Total stations: 277
# Stations in urban areas with pop >5m: 55
# Stations in urban areas with pop >3m: 101
# Stations in urban areas with pop >2m: 131
# Stations in urban areas with pop >1m: 194
# Stations in urban areas with pop >500k: 234
# Stations in urban areas with pop >100k: 268
# Stations in urban areas with pop >50k: 274
# Total population in urban area of stations: 910208188.0
#                      station      lat      long country_code  population  \
# 0                    Abidjan   5.3200   -4.0400          CIV   3802000.0
# 1                  Abu Dhabi  24.4667   54.3666          ARE    603492.0
# 2                      Abuja   9.0833    7.5333          NGA   1576000.0
# 3                      Accra   5.5500   -0.2167          GHA   2121000.0
# 4                Addis Ababa   9.0333   38.7000          ETH   3100000.0
# 5                  Ahmadabad  23.0301   72.5800          IND   5375000.0
# 6                 Alexandria  31.2000   29.9500          EGY   4165000.0
# 7                    Algiers  36.7631    3.0506          DZA   3354000.0
# 8                     Almaty  43.3250   76.9150          KAZ   1209000.0
# 9                      Amman  31.9500   35.9333          JOR   1060000.0
# 10                 Amsterdam  52.3500    4.9166          NLD   1031000.0
# 11                 Anchorage  61.1508 -149.1091          USA    253421.0
# 12                    Ankara  39.9272   32.8644          TUR   3716000.0
# 13              Antananarivo -18.9166   47.5166          MDG   1697000.0
# 14                  Ashgabat  37.9500   58.3833          TKM    727700.0
# 15                    Asmara  15.3333   38.9333          ERI    620802.0
# 16                  Asuncion -25.2964  -57.6415          PRY   1870000.0
# 17                    Athens  37.9833   23.7333          GRC   3242000.0
# 18                   Atlanta  33.7627  -84.4225          USA   5228750.0
# 19                  Auckland -36.8481  174.7630          NZL   1377200.0
# 20                   Baghdad  33.3386   44.3939          IRQ   5054000.0
# 21                      Baku  40.3953   49.8622          AZE   2122300.0
# 22                      Bali  -8.6500  115.2200          IDN    732344.0
# 23                    Bamako  12.6500   -8.0000          MLI   1494000.0
# 24       Bandar Seri Begawan   4.8833  114.9333          BRN    296500.0
# 25                 Bangalore  12.9700   77.5600          IND   6787000.0
# 26                   Bangkok  13.7500  100.5166          THA   6704000.0
# 27                    Bangui   4.3666   18.5583          CAF    831925.0
# 28                    Banjul  13.4539  -16.5917          GMB     43094.0
# 29                 Barcelona  41.3833    2.1834          ESP   4920000.0
# 30               Basse-Terre  16.0000  -61.7167          GLP     10226.0
# 31                      Bata   1.8700    9.7700          GNQ    173046.0
# 32                   Beijing  39.9289  116.3883          CHN  11106000.0
# 33                    Beirut  33.8720   35.5097          LBN   1846000.0
# 34                  Belgrade  44.8186   20.4680          SRB   1099000.0
# 35               Belize City  17.4987  -88.1884          BLZ     63028.0
# 36            Belo Horizonte -19.9150  -43.9150          BRA   5575000.0
# 37                    Berlin  52.5218   13.4015          DEU   3406000.0
# 38                   Bishkek  42.8731   74.5852          KGZ    837000.0
# 39                    Bissau  11.8650  -15.5984          GNB    403339.0
# 40                    Bogota   4.5964  -74.0833          COL   7772000.0
# 41                    Boston  42.3188  -71.0846          USA   4637537.0
                station_dict[station][field] += [line_dict[line][i-1] + '_' + line] if i > 0 else [] # station before
                station_dict[station][field] += [line_dict[line][i+1] + '_' + line] if i < len(line_dict[line])-1 else [] # station after
            else: # branch line
                split_station, main_line, direction = line.split('_')
                station_dict[station]['lines'].add(main_line)
                if i == 0:
#                     print(line_dict[line])

#                     ml_station = line_dict[main_line]
#                     ml_split_index = ml_station.index(split_station)
                    
#                     previous_station = ml_station[ml_split_index-1] if direction == 'R' else ml_station[ml_split_index+1]
#                     print(previous_station, split_station)
#                     station_dict[previous_station][field] += [split_station + '_' + main_line]
#                     station_dict[split_station][field] += [previous_station + '_' + main_line]
                    station_dict[station][field] += [split_station + '_' + main_line]
                    station_dict[split_station][field] += [station + '_' + main_line]
                station_dict[station][field] += [line_dict[line][i-1] + '_' + main_line] if i > 0 else [] # station before
                station_dict[station][field] += [line_dict[line][i+1] + '_' + main_line] if i < len(line_dict[line])-1 else [] # station after
    return station_dict

def dict_to_df(row):
    row['lines'] = ','.join(station_dict[row['station']]['lines'])
    row['line_num'] = len(station_dict[row['station']]['lines'])
    row['transfer'] = True if row['line_num'] > 1 else False
    row['type'] = 'EXPRESS' if row['transfer'] or row['population'] > EXPRESS_POP_CUTOFF else 'LOCAL'
    return row


def dict_to_df_station_list(row):
    row['next_local_stations'] = ','.join(station_dict[row['station']]['next_local_stations'])
    row['next_express_stations'] = ','.join(station_dict[row['station']]['next_express_stations']) if station_dict[row['station']]['next_express_stations'] != [] else '' 
    return row



station_dict = {station: {'lines': set(), 'next_local_stations': [], 'next_express_stations': []} for station in station_set}


# add lines to station dict
for line in line_dict:
    for i, station in enumerate(line_dict[line]):
        if '_' not in line: # main line
            station_dict[station]['lines'].add(line)
        else: # branch line
            split_station, main_line, direction = line.split('_')
            station_dict[station]['lines'].add(main_line)

            
            
            
# add lines, line_num, transfer, and type (express/local) to dataframe
station_df = station_df.apply(dict_to_df, axis=1)



# generate a dict of express stations to get express stations
express_line_dict = {}
express_inters = {}
for line in line_dict:
    new_line_list = []
    temp_inters = []
    
    if '_' not in line: # main line
        previous_express = None
        for station in line_dict[line]:
            if station_df.set_index('station').at[station, 'type'] == 'EXPRESS':
                new_line_list.append(station)
                
                # intermediate stations
                if previous_express is not None: # end and start
                    temp_inters.append(station+'_'+line)
                    express_inters[(previous_express+'_'+line, station+'_'+line)] = temp_inters
                temp_inters = [station+'_'+line] # start
                previous_express = station
            else:
                temp_inters.append(station+'_'+line)

    else: # branch line
        split_station, main_line, direction = line.split('_')
        
        # split station is an express station = normal
        if station_df.set_index('station').at[split_station, 'type'] == 'EXPRESS':
            previous_express = split_station

        # need to backtrack and change name of line to nearest express station
        else: 
            split_station_i = line_dict[main_line].index(split_station)
            earlier_stations = line_dict[main_line][split_station_i:] if direction == 'L' else line_dict[main_line][0:split_station_i][::-1]
            for sstation in earlier_stations:
                if station_df.set_index('station').at[sstation, 'type'] == 'EXPRESS':
                    split_station = sstation
                    break # last express station found
        
        previous_express = split_station
        temp_inters = [previous_express+'_'+main_line]
        for station in line_dict[line]:
            if station_df.set_index('station').at[station, 'type'] == 'EXPRESS':
                new_line_list.append(station)

                # intermediate stations
                temp_inters.append(station+'_'+main_line)
                express_inters[(previous_express+'_'+main_line, station+'_'+main_line)] = temp_inters
                temp_inters = [station+'_'+main_line] # start
                previous_express = station
            else:
                temp_inters.append(station+'_'+main_line)
    
        line = split_station + '_' + main_line + '_' + direction            
    express_line_dict[line] = new_line_list


# get next local stations
get_next_stations_from_line_dict(line_dict, station_dict, 'next_local_stations')
get_next_stations_from_line_dict(express_line_dict, station_dict, 'next_express_stations')


station_df = station_df.apply(dict_to_df_station_list, axis=1)

print('Total transfer stations:', station_df[station_df['transfer']].shape[0])
print('Hub stations (3 lines):', station_df[station_df['line_num'] == 3].shape[0])
print('Superhub stations (4+ lines):', station_df[station_df['line_num'] >= 4].shape[0])
print('Express stations:', station_df[station_df['type'] == 'EXPRESS'].shape[0], 'out of', station_df.shape[0])

station_df
# Out:
# Total transfer stations: 106
# Hub stations (3 lines): 13
# Superhub stations (4+ lines): 12
# Express stations: 161 out of 277
#                      station      lat      long country_code  population  \
# 0                    Abidjan   5.3200   -4.0400          CIV   3802000.0
# 1                  Abu Dhabi  24.4667   54.3666          ARE    603492.0
# 2                      Abuja   9.0833    7.5333          NGA   1576000.0
# 3                      Accra   5.5500   -0.2167          GHA   2121000.0
# 4                Addis Ababa   9.0333   38.7000          ETH   3100000.0
# 5                  Ahmadabad  23.0301   72.5800          IND   5375000.0
# 6                 Alexandria  31.2000   29.9500          EGY   4165000.0
# 7                    Algiers  36.7631    3.0506          DZA   3354000.0
# 8                     Almaty  43.3250   76.9150          KAZ   1209000.0
# 9                      Amman  31.9500   35.9333          JOR   1060000.0
# 10                 Amsterdam  52.3500    4.9166          NLD   1031000.0
# 11                 Anchorage  61.1508 -149.1091          USA    253421.0
# 12                    Ankara  39.9272   32.8644          TUR   3716000.0
# 13              Antananarivo -18.9166   47.5166          MDG   1697000.0
# 14                  Ashgabat  37.9500   58.3833          TKM    727700.0
# 15                    Asmara  15.3333   38.9333          ERI    620802.0
# 16                  Asuncion -25.2964  -57.6415          PRY   1870000.0
# 17                    Athens  37.9833   23.7333          GRC   3242000.0
# 18                   Atlanta  33.7627  -84.4225          USA   5228750.0
# 19                  Auckland -36.8481  174.7630          NZL   1377200.0
# 20                   Baghdad  33.3386   44.3939          IRQ   5054000.0
# 21                      Baku  40.3953   49.8622          AZE   2122300.0
# 22                      Bali  -8.6500  115.2200          IDN    732344.0
# 23                    Bamako  12.6500   -8.0000          MLI   1494000.0
# 24       Bandar Seri Begawan   4.8833  114.9333          BRN    296500.0
# 25                 Bangalore  12.9700   77.5600          IND   6787000.0
# 26                   Bangkok  13.7500  100.5166          THA   6704000.0
# 27                    Bangui   4.3666   18.5583          CAF    831925.0
# 28                    Banjul  13.4539  -16.5917          GMB     43094.0
# 29                 Barcelona  41.3833    2.1834          ESP   4920000.0
# 30               Basse-Terre  16.0000  -61.7167          GLP     10226.0
# 31                      Bata   1.8700    9.7700          GNQ    173046.0
# 205                                Trinidad and Tobago  Americas
# 206                                              Haiti  Americas
# 207                                            Czechia    Europe
# 208                                              India      Asia
# 209            Korea (Democratic People's Republic of)      Asia
# 210                                            Ecuador  Americas
# 211                                            Iceland    Europe
# 212                                             Latvia    Europe
# 213                                             Brazil  Americas
# 214                                       Saudi Arabia      Asia
# 215                                              Italy    Europe
# 216                                 Russian Federation    Europe
# 217                                            Réunion    Africa
# 218                                             Brazil  Americas
# 219                           United States of America  Americas
# 220                                         Costa Rica  Americas
# 221                                        Puerto Rico  Americas
# 222                                        El Salvador  Americas
# 223                                              Yemen      Asia
# 224                   Bolivia (Plurinational State of)  Americas
# 225                                              Chile  Americas
# 226                                 Dominican Republic  Americas
# 227                                              China      Asia
# 228                                             Brazil  Americas
# 229                                              Japan      Asia
# 230                             Bosnia and Herzegovina    Europe
# 231                           United States of America  Americas
# 232                                 Korea, Republic of      Asia
# 233                                            Ukraine    Europe
# 234                                              China      Asia
# 235                                              China      Asia
# 236                                              China      Asia
# 237                                          Singapore      Asia
# 238                                    North Macedonia    Europe
# 239                                           Bulgaria    Europe
# 240                                             Sweden    Europe
# 241                                          Indonesia      Asia
# 242                                              India      Asia
# 243                                               Fiji   Oceania
# 244                                          Australia   Oceania
# 245                          Taiwan, Province of China      Asia
# 246                                            Estonia    Europe
# 247                                         Uzbekistan      Asia
# 248                                            Georgia      Asia
# 249                                           Honduras  Americas
# 250                         Iran (Islamic Republic of)      Asia
# 251                                             Bhutan      Asia
# 252                                              China      Asia
# 253                                            Albania    Europe
# 254                                              Japan      Asia
# 255                                             Canada  Americas
# 256                                              Libya    Africa
# 257                                            Tunisia    Africa
# 258                                           Mongolia      Asia
# 259                                              China      Asia
# 260                                             Canada  Americas
# 261                                            Austria    Europe
# 262                   Lao People's Democratic Republic      Asia
# 263                                          Lithuania    Europe
# 264                                 Russian Federation    Europe
# 265                                             Poland    Europe
# 266                           United States of America  Americas
# 267                                            Namibia    Africa
# 268                                             Canada  Americas
# 269                                              China      Asia
# 270                                              China      Asia
# 271                                            Myanmar      Asia
# 272                                           Cameroon    Africa
# 273                                 Russian Federation    Europe
# 274                                            Armenia      Asia
# 275                                            Croatia    Europe
# 276                                        Switzerland    Europe
#
#                           sub_region                              lines  \
# 0                 Sub-Saharan Africa                             BRONZE
# 1                       Western Asia                       LILAC,SILVER
# 2                 Sub-Saharan Africa                                RED
# 3                 Sub-Saharan Africa                        NAVY,BRONZE
# 4                 Sub-Saharan Africa                    BLUE,LIGHTGREEN
# 5                      Southern Asia                       LILAC,SILVER
# 6                    Northern Africa                             SILVER
# 7                    Northern Africa                             SILVER
# 8                       Central Asia                               AQUA
# 9                       Western Asia                      SILVER,BRONZE
# 10                    Western Europe                      RED,DARKGREEN
# 11                  Northern America                             ORANGE
# 12                      Western Asia                        AQUA,BRONZE
# 13                Sub-Saharan Africa                               BLUE
# 14                      Central Asia                               AQUA
# 15                Sub-Saharan Africa                         LIGHTGREEN
# 16   Latin America and the Caribbean                                RED
# 17                   Southern Europe                    LILAC,DARKGREEN
# 18                  Northern America                      PURPLE,BRONZE
# 19         Australia and New Zealand                               AQUA
# 20                      Western Asia                         LIGHTGREEN
# 21                      Western Asia                               AQUA
# 22                South-eastern Asia                    AQUA,LIGHTGREEN
# 23                Sub-Saharan Africa                        NAVY,BRONZE
# 24                South-eastern Asia                             SILVER
# 25                     Southern Asia                        BLUE,SILVER
# 26                South-eastern Asia    LILAC,AQUA,LIGHTGREEN,DARKGREEN
# 27                Sub-Saharan Africa                        NAVY,BRONZE
# 28                Sub-Saharan Africa                             BRONZE
# 29                   Southern Europe                   DARKGREEN,BRONZE
# 30   Latin America and the Caribbean                             PURPLE
# 31                Sub-Saharan Africa                             BRONZE
# 32                      Eastern Asia          ORANGE,RED,AQUA,DARKGREEN
# 33                      Western Asia                  LIGHTGREEN,BRONZE
# 34                   Southern Europe                             BRONZE
# 35   Latin America and the Caribbean                             PURPLE
# 36   Latin America and the Caribbean                             BRONZE
# 37                    Western Europe                    LILAC,DARKGREEN
# 38                      Central Asia                               AQUA
# 39                Sub-Saharan Africa                             BRONZE
# 40   Latin America and the Caribbean                         ORANGE,RED
# 41                  Northern America                      ORANGE,BRONZE
# 42   Latin America and the Caribbean                             BRONZE
# 43                    Eastern Europe                             BRONZE
# 44                Sub-Saharan Africa                         LIGHTGREEN
# 45   Latin America and the Caribbean                             PURPLE
# 46         Australia and New Zealand                             ORANGE
# 47                    Western Europe                         RED,BRONZE
# 48                    Eastern Europe                              LILAC
# 49                    Eastern Europe                             BRONZE
# 50   Latin America and the Caribbean                      ORANGE,BRONZE
# 51                Sub-Saharan Africa                         LIGHTGREEN
# 52                      Eastern Asia                          NAVY,AQUA
# 53                   Northern Africa  LILAC,LIGHTGREEN,SILVER,DARKGREEN
# 54                  Northern America                             PURPLE
# 55                Sub-Saharan Africa                    BLUE,LIGHTGREEN
# 56   Latin America and the Caribbean                         RED,BRONZE
# 57                   Northern Africa                      SILVER,BRONZE
# 58   Latin America and the Caribbean                             BRONZE
# 59                      Eastern Asia                     NAVY,DARKGREEN
# 60                     Southern Asia                               BLUE
# 61                  Northern America                   ORANGE,DARKGREEN
# 62                    Eastern Europe                              LILAC
# 63                     Southern Asia                         LIGHTGREEN
# 64                      Eastern Asia                               NAVY
# 65         Australia and New Zealand                               AQUA
# 66                     Southern Asia                             SILVER
# 67                Sub-Saharan Africa                             BRONZE
# 68                   Northern Europe                          RED,LILAC
# 69                Sub-Saharan Africa                             BRONZE
# 70                Sub-Saharan Africa                        NAVY,BRONZE
# 71                      Eastern Asia                               AQUA
# 72                  Northern America                             ORANGE
# 73                      Western Asia                         LIGHTGREEN
# 74                Sub-Saharan Africa                               BLUE
# 75                South-eastern Asia                             ORANGE
# 76                     Southern Asia               BLUE,NAVY,LIGHTGREEN
# 77                  Northern America                          DARKGREEN
# 78                     Southern Asia                   LILAC,LIGHTGREEN
# 79                South-eastern Asia                  ORANGE,LIGHTGREEN
# 80                Sub-Saharan Africa                               BLUE
# 81                      Western Asia                        BLUE,BRONZE
# 82                Sub-Saharan Africa                             BRONZE
# 83                      Western Asia           BLUE,LILAC,SILVER,BRONZE
# 84                   Northern Europe                             BRONZE
# 85                      Central Asia                               AQUA
# 86   Latin America and the Caribbean                             PURPLE
# 87   Latin America and the Caribbean                                RED
# 88                    Western Europe                             BRONZE
# 89                Sub-Saharan Africa                             BRONZE
# 90                      Eastern Asia                          NAVY,AQUA
# 91                Sub-Saharan Africa                             BRONZE
# 92   Latin America and the Caribbean                             BRONZE
# 93                   Northern Europe                               AQUA
# 94   Latin America and the Caribbean                             ORANGE
# 95                      Eastern Asia                             ORANGE
# 96   Latin America and the Caribbean                      ORANGE,PURPLE
# 97                      Eastern Asia                           RED,AQUA
# 98                South-eastern Asia                               AQUA
# 99                Sub-Saharan Africa                               BLUE
# 100                     Eastern Asia                             ORANGE
# 101  Latin America and the Caribbean                             BRONZE
# 102                  Northern Europe                          RED,LILAC
# ...
# 274                           Ankara_AQUA,Tbilisi_AQUA
# 275  Ljubljana_AQUA,Sarajevo_AQUA,Rome_LILAC,Vienna...
# 276                          Paris_AQUA,Ljubljana_AQUA
#
#                                  next_express_stations
# 0                            Dakar_BRONZE,Accra_BRONZE
# 1    Riyadh_SILVER,Dubai_SILVER,Dubai_LILAC,Riyadh_...
# 2
# 3    Abidjan_BRONZE,Lagos_BRONZE,Ouagadougou_NAVY,L...
# 4    Mogadishu_LIGHTGREEN,Khartoum_LIGHTGREEN,Nairo...
# 5    Surat_SILVER,Mumbai_SILVER,Surat_LILAC,Karachi...
# 6                          Tripoli_SILVER,Cairo_SILVER
# 7                       Casablanca_SILVER,Tunis_SILVER
# 8
# 9    Beirut_BRONZE,Doha_BRONZE,Jerusalem_SILVER,Riy...
# 10   Brussels_RED,Copenhagen_RED,London_DARKGREEN,B...
# 11
# 12   Istanbul_BRONZE,Beirut_BRONZE,Istanbul_AQUA,Ba...
# 13
# 14
# 15
# 16
# 17   Cairo_LILAC,Istanbul_LILAC,Rome_LILAC,Rome_DAR...
# 18   New York City_PURPLE,Houston_PURPLE,Miami_BRON...
# 19
# 20               Damascus_LIGHTGREEN,Tehran_LIGHTGREEN
# 21                             Ankara_AQUA,Tehran_AQUA
# 22   Surabaya_AQUA,Melbourne_AQUA,Jakarta_LIGHTGREE...
# 23   Casablanca_BRONZE,Ouagadougou_BRONZE,Dakar_NAV...
# 24
# 25   Pune_SILVER,Medan_SILVER,Hyderabad_BLUE,Chenna...
# 26   Hanoi_AQUA,Kuala Lumpur_AQUA,Yangon_LIGHTGREEN...
# 27   Kano_BRONZE,Kampala_BRONZE,Lagos_NAVY,Nairobi_...
# 28
# 29   Paris_BRONZE,Casablanca_BRONZE,Madrid_DARKGREE...
# 30
# 31
# 32   Shenyang_ORANGE,Wuhan_ORANGE,Moscow_RED,Jinan_...
# 33   Ankara_BRONZE,Amman_BRONZE,Jerusalem_LIGHTGREE...
# 34
# 35
# 36               Rio de Janeiro_BRONZE,Brasilia_BRONZE
# 37   Prague_LILAC,Copenhagen_LILAC,Amsterdam_DARKGR...
# 38
# 39
# 40   Quito_ORANGE,Medellin_ORANGE,Caracas_RED,Quito...
# 41   New York City_ORANGE,New York City_BRONZE,Lond...
# 42          Belo Horizonte_BRONZE,Port of Spain_BRONZE
# 43
# 44
# 45
# 46
# 47   Paris_RED,Amsterdam_RED,London_BRONZE,Frankfur...
# 48
# 49
# 50   Montevideo_ORANGE,Santiago_ORANGE,Santiago_BRO...
# 51
# 52     Seoul_AQUA,Fukuoka_AQUA,Seoul_NAVY,Fukuoka_NAVY
# 53   Alexandria_SILVER,Jerusalem_SILVER,Khartoum_LI...
# 54
# 55                 Luanda_LIGHTGREEN,Johannesburg_BLUE
# 56   Bogota_RED,Port of Spain_BRONZE,Santo Domingo_...
# 57   Barcelona_BRONZE,Dakar_BRONZE,Bamako_BRONZE,Ma...
# 58
# 59   Delhi_NAVY,Chongqing_NAVY,Xi'an_DARKGREEN,Bang...
# 60                                      Bangalore_BLUE
# 61   Seattle_ORANGE,Washington D.C._ORANGE,Denver_D...
# 62
# 63                  Dhaka_LIGHTGREEN,Yangon_LIGHTGREEN
# 64                             Chengdu_NAVY,Wuhan_NAVY
# 65
# 66
# 67
# 68             Amsterdam_RED,Helsinki_RED,Berlin_LILAC
# 69
# 70        Casablanca_BRONZE,Abidjan_BRONZE,Bamako_NAVY
# 71                             Tianjin_AQUA,Seoul_AQUA
# 72                       Phoenix_ORANGE,Houston_ORANGE
# 73                Beirut_LIGHTGREEN,Baghdad_LIGHTGREEN
# 74                      Johannesburg_BLUE,Nairobi_BLUE
# 75
# 76   Mumbai_NAVY,Chengdu_NAVY,Lahore_LIGHTGREEN,Luc...
# 77               Las Vegas_DARKGREEN,Chicago_DARKGREEN
# 78   Lucknow_LIGHTGREEN,Chittagong_LIGHTGREEN,Yango...
# 79         Manila_ORANGE,Sydney_ORANGE,Bali_LIGHTGREEN
# 80
# 81   Amman_BRONZE,Dubai_BRONZE,Dubai_BLUE,Kuwait Ci...
# 82
# 83   Doha_BRONZE,Abu Dhabi_SILVER,Muscat_SILVER,San...
# 84
# 85
# 86
# 87                              Salvador_RED,Lagos_RED
# 88                       Brussels_BRONZE,Prague_BRONZE
# 89
# 90         Busan_AQUA,Osaka_AQUA,Busan_NAVY,Osaka_NAVY
# 91
# 92
# 93
# 94               Mexico City_ORANGE,Los Angeles_ORANGE
# 95                        Wuhan_ORANGE,Shenzhen_ORANGE
# 96   Medellin_ORANGE,Mexico City_ORANGE,Mexico City...
# 97   Shanghai_RED,Taipei_RED,Shanghai_AQUA,Taipei_AQUA
# 98                             Macau_AQUA,Bangkok_AQUA
# 99
# 100                  Khabarovsk_ORANGE,Shenyang_ORANGE
# 101                       Kingston_BRONZE,Miami_BRONZE
# 102  Copenhagen_RED,Saint Petersburg_RED,Kyiv_LILAC...
# 103            Bangkok_LIGHTGREEN,Singapore_LIGHTGREEN
# 104  Shenzhen_ORANGE,Manila_ORANGE,Taipei_RED,Macau...
# 105
# 106
# 107  Dallas_ORANGE,Miami_ORANGE,Atlanta_PURPLE,Mont...
# 108  Nagpur_BLUE,Bangalore_BLUE,Kolkata_LILAC,Mumba...
# 109
# 110
# 111  Prague_BRONZE,Ankara_BRONZE,Zagreb_AQUA,Ankara...
# 112  Singapore_AQUA,Surabaya_AQUA,Singapore_LIGHTGR...
# 113                           Riyadh_LILAC,Cairo_LILAC
# 114  Cairo_SILVER,Amman_SILVER,Cairo_LIGHTGREEN,Bei...
# 115                           Beijing_RED,Shanghai_RED
# 116    Luanda_BRONZE,Cape Town_BLUE,Dar es Salaam_BLUE
# 117
# 118               Mashhad_LIGHTGREEN,Lahore_LIGHTGREEN
# 119  Bangui_BRONZE,Nairobi_BRONZE,Kinshasa_LIGHTGRE...
# 120  Lagos_RED,Tunis_RED,Ouagadougou_BRONZE,Bangui_...
# 121  Muscat_SILVER,Surat_SILVER,Tehran_BLUE,Lahore_...
# 122
# 123
# 124  Vancouver_ORANGE,Harbin_ORANGE,Moscow_RED,Sapp...
# 125            Addis Ababa_LIGHTGREEN,Cairo_LIGHTGREEN
# 126
# 127  Guatemala City_PURPLE,Port-au-Prince_PURPLE,Po...
# 128               Luanda_LIGHTGREEN,Kampala_LIGHTGREEN
# 129                        Dhaka_LILAC,Hyderabad_LILAC
# 130
# 131  Bangkok_AQUA,Singapore_AQUA,Medan_SILVER,Singa...
# 132                              Doha_BLUE,Tehran_BLUE
# 133  Istanbul_LILAC,Helsinki_LILAC,Berlin_DARKGREEN...
# 134  Santiago_ORANGE,Lima_ORANGE,Lima_RED,Sao Paulo...
# 135
# 136  Fortaleza_RED,Kano_RED,Accra_BRONZE,Luanda_BRO...
# 137  Kabul_LIGHTGREEN,Delhi_LIGHTGREEN,Karachi_BLUE...
# 138             Los Angeles_DARKGREEN,Denver_DARKGREEN
# 139
# 140
# 141    La Paz_ORANGE,Quito_ORANGE,Quito_RED,La Paz_RED
# 142           New York City_DARKGREEN,Madrid_DARKGREEN
# 143
# 144
# 145  Boston_BRONZE,Paris_BRONZE,Brussels_BRONZE,Par...
# 146  Guadalajara_ORANGE,San Francisco_ORANGE,Phoeni...
# 147  Lagos_BRONZE,Johannesburg_BRONZE,Cape Town_LIG...
# 148
# 149                  Delhi_LIGHTGREEN,Dhaka_LIGHTGREEN
# 150
# 151
# 152            Hong Kong_RED,Hong Kong_AQUA,Hanoi_AQUA
# 153  London_SILVER,Casablanca_SILVER,Lisbon_DARKGRE...
# 154
# 155
# 156
# 157
# 158  Hong Kong_ORANGE,Dili_ORANGE,Singapore_SILVER,...
# 159
# 160
# 161                 Tehran_LIGHTGREEN,Kabul_LIGHTGREEN
# 162
# 163               Bangalore_SILVER,Kuala Lumpur_SILVER
# 164                Bogota_ORANGE,Guatemala City_ORANGE
# 165                Sydney_ORANGE,Bali_AQUA,Sydney_AQUA
# 166  Guatemala City_ORANGE,Guadalajara_ORANGE,Monte...
# 167        Houston_ORANGE,Havana_BRONZE,Atlanta_BRONZE
# 168  Rome_RED,Paris_RED,Barcelona_DARKGREEN,Rome_DA...
# 169
# 170  Nairobi_NAVY,Mumbai_NAVY,Nairobi_LIGHTGREEN,Ad...
# 171
# 172
# 173
# 174                  Houston_PURPLE,Mexico City_PURPLE
# 175  Sao Paulo_ORANGE,Buenos Aires_ORANGE,Buenos Ai...
# 176                Toronto_PURPLE,New York City_PURPLE
# 177
# 178  Saint Petersburg_RED,Beijing_RED,Khabarovsk_RE...
# 179  Ahmadabad_SILVER,Pune_SILVER,Mogadishu_NAVY,De...
# 180  Dubai_SILVER,Karachi_SILVER,Karachi_LILAC,Duba...
# 181
# 182
# 183                          Delhi_BLUE,Hyderabad_BLUE
# 184  Kampala_BRONZE,Bangui_NAVY,Mogadishu_NAVY,Kamp...
# 185                           Wuhan_NAVY,Shanghai_NAVY
# 186
# 187  Washington D.C._ORANGE,Boston_ORANGE,Montreal_...
# 188
# 189
# 190
# 191
# 192    Fukuoka_AQUA,Tokyo_AQUA,Fukuoka_NAVY,Tokyo_NAVY
# 193
# 194
# 195   Bamako_BRONZE,Kano_BRONZE,Bamako_NAVY,Accra_NAVY
# 196
# 197
# 198  Milan_RED,Brussels_RED,London_BRONZE,Barcelona...
# 199
# 200
# 201                   Los Angeles_ORANGE,Dallas_ORANGE
# 202
# 203
# 204
# 205  Santo Domingo_PURPLE,Brasilia_BRONZE,Caracas_B...
# 206  Kingston_PURPLE,Santo Domingo_PURPLE,Santo Dom...
# 207  Frankfurt_BRONZE,Istanbul_BRONZE,Vienna_LILAC,...
# 208                     Mumbai_SILVER,Bangalore_SILVER
# 209                       Seoul_SILVER,Shenyang_SILVER
# 210      Lima_ORANGE,Bogota_ORANGE,Bogota_RED,Lima_RED
# 211
# 212
# 213  Sao Paulo_ORANGE,Sao Paulo_RED,Salvador_RED,Sa...
# 214  Amman_SILVER,Abu Dhabi_SILVER,Abu Dhabi_LILAC,...
# 215  Tunis_RED,Milan_RED,Athens_LILAC,Zagreb_LILAC,...
# 216  Helsinki_RED,Moscow_RED,Helsinki_LILAC,Moscow_...
# 217
# 218                   Rio de Janeiro_RED,Fortaleza_RED
# 219                  Los Angeles_ORANGE,Seattle_ORANGE
# 220
# 221
# 222
# 223                        Addis Ababa_BLUE,Dubai_BLUE
# 224
# 225  Buenos Aires_ORANGE,La Paz_ORANGE,Buenos Aires...
# 226  Port-au-Prince_PURPLE,Port of Spain_PURPLE,Car...
# 227
# 228  Rio de Janeiro_ORANGE,Montevideo_ORANGE,La Paz...
# 229                           Khabarovsk_RED,Tokyo_RED
# 230
# 231  San Francisco_ORANGE,Vancouver_ORANGE,Chicago_...
# 232  Dalian_AQUA,Busan_AQUA,Taipei_SILVER,Pyongyang...
# 233
# 234  Jinan_RED,Hangzhou_RED,Tianjin_AQUA,Hangzhou_A...
# 235      Harbin_ORANGE,Beijing_ORANGE,Pyongyang_SILVER
# 236                  Guangzhou_ORANGE,Hong Kong_ORANGE
# 237  Kuala Lumpur_AQUA,Jakarta_AQUA,Kuala Lumpur_SI...
# 238
# 239
# 240
# 241                             Jakarta_AQUA,Bali_AQUA
# 242  Karachi_SILVER,Ahmadabad_SILVER,Mumbai_LILAC,A...
# 243
# 244        Dili_ORANGE,Melbourne_ORANGE,Melbourne_AQUA
# 245  Hangzhou_RED,Hong Kong_RED,Hangzhou_AQUA,Hong ...
# 246
# 247                            Tehran_AQUA,Urumqi_AQUA
# 248
# 249
# 250  Baku_AQUA,Tashkent_AQUA,Baghdad_LIGHTGREEN,Mas...
# 251
# 252             Beijing_AQUA,Shanghai_AQUA,Dalian_AQUA
# 253
# 254  Sapporo_RED,Osaka_AQUA,Osaka_NAVY,Seoul_DARKGR...
# 255  Vancouver_PURPLE,Montreal_PURPLE,Chicago_DARKG...
# 256                     Tunis_SILVER,Alexandria_SILVER
# 257    Kano_RED,Rome_RED,Algiers_SILVER,Tripoli_SILVER
# 258
# 259                           Tashkent_AQUA,Xi'an_AQUA
# 260    Seattle_ORANGE,Khabarovsk_ORANGE,Toronto_PURPLE
# 261                          Zagreb_LILAC,Prague_LILAC
# 262
# 263
# 264
# 265
# 266  Chicago_ORANGE,New York City_ORANGE,Atlanta_BR...
# 267
# 268
# 269  Beijing_ORANGE,Guangzhou_ORANGE,Chongqing_NAVY...
# 270  Urumqi_AQUA,Beijing_AQUA,Beijing_DARKGREEN,Che...
# 271  Chittagong_LIGHTGREEN,Bangkok_LIGHTGREEN,Bangk...
# 272
# 273
# 274
# 275   Paris_AQUA,Istanbul_AQUA,Rome_LILAC,Vienna_LILAC
# 276

# %%
# get distances + times between each pair of adjacent stations - edges of the graph!

def get_time_from_dist(dist_km): # in km
    '''
    Returns tuple (dist, time, max_speed, avg_speed) for time in seconds,
    max speed reached in km/h, and average speed for trip im km/h
    '''
    dist = dist_km*1000
    if dist > 2 * ACC_DISTANCE: # can fully accelerate to maximum speed
        max_speed_dist = dist - 2*ACC_DISTANCE
        time = 2*ACC_TIME + max_speed_dist/MAX_SPEED
        return int(dist_km), int(time), int(MAX_SPEED_KMH), int(dist_km/(time/3600))
    else: # distance too short, cannot accelerate fully
        acc_dist = dist/2
        acc_time = math.sqrt(2 * acc_dist/ACCELERATION) # from d = 1/2 at^2
        time = acc_time * 2
        return int(dist_km), int(time), int(acc_time * ACCELERATION * 3.6), int(dist_km/(time/3600))
    
    
station_durs = []

for i, row in station_df.iterrows():
    station_df_set = station_df.set_index('station')
    station_strip = row['station']
    all_station_lines = [station_strip + '_' + line for line in station_df_set.at[station_strip, 'lines'].split(',')]
    station_coord = (station_df_set.at[station_strip, 'lat'], station_df_set.at[station_strip, 'long'])
    next_local = row['next_local_stations'].split(',')
    next_express = row['next_express_stations'].split(',')
    for next_st in next_local:
        next_st_strip, next_line = next_st.split('_')
        next_coord = (station_df_set.at[next_st_strip, 'lat'], station_df_set.at[next_st_strip, 'long'])
        for station in all_station_lines:
            station_line = station.split('_')[1]
            if station_line == next_line: 
                station_durs.append((station+'_'+'LOCAL', next_st+'_'+'LOCAL', get_time_from_dist(distance.distance(station_coord, next_coord).km)))
    if next_express == ['']:
        continue
    for next_st in next_express:
        next_st_strip, next_line = next_st.split('_')
        for station in all_station_lines:
            station_line = station.split('_')[1]
            if station_line == next_line:
#                 print(station, next_st)
                next_inters = express_inters[(station, next_st)] if (station, next_st) in express_inters else express_inters[(next_st, station)]
#                 print(next_inters)
                total_exp_dist = 0
                for j in range(len(next_inters)-1): # add up distances through intermediate stations
                    station1, station2 = next_inters[j], next_inters[j+1]
                    station1_strip, station1_line = station1.split('_')
                    station2_strip, station2_line = station2.split('_')
                    station1_coord = (station_df_set.at[station1_strip, 'lat'], station_df_set.at[station1_strip, 'long'])
                    station2_coord = (station_df_set.at[station2_strip, 'lat'], station_df_set.at[station2_strip, 'long'])
                    total_exp_dist += distance.distance(station1_coord, station2_coord).km
#                 print(total_exp_dist)
#                 print()
                station_durs.append((station+'_'+'EXPRESS', next_st+'_'+'EXPRESS', get_time_from_dist(total_exp_dist)))


print(len(station_durs))
print('Longest streteches between stations')
sorted(station_durs, key=lambda x: x[2][0], reverse=True)[:20]
# Out:
# 1404
# Longest streteches between stations
# [('Los Angeles_DARKGREEN_EXPRESS',
#   'Tokyo_DARKGREEN_EXPRESS',
#   (10318, 31066, 1200, 1195)),
#  ('Tokyo_DARKGREEN_EXPRESS',
#   'Los Angeles_DARKGREEN_EXPRESS',
#   (10318, 31066, 1200, 1195)),
#  ('Khabarovsk_ORANGE_EXPRESS',
#   'Vancouver_ORANGE_EXPRESS',
#   (6863, 20700, 1200, 1193)),
#  ('Vancouver_ORANGE_EXPRESS',
#   'Khabarovsk_ORANGE_EXPRESS',
#   (6863, 20700, 1200, 1193)),
#  ('Honolulu_DARKGREEN_LOCAL',
#   'Tokyo_DARKGREEN_LOCAL',
#   (6209, 18740, 1200, 1192)),
#  ('Tokyo_DARKGREEN_LOCAL',
#   'Honolulu_DARKGREEN_LOCAL',
#   (6209, 18740, 1200, 1192)),
#  ('Khabarovsk_RED_EXPRESS', 'Moscow_RED_EXPRESS', (6163, 18601, 1200, 1192)),
#  ('Moscow_RED_EXPRESS', 'Khabarovsk_RED_EXPRESS', (6163, 18601, 1200, 1192)),
#  ('Beijing_RED_EXPRESS', 'Moscow_RED_EXPRESS', (6022, 18178, 1200, 1192)),
#  ('Moscow_RED_EXPRESS', 'Beijing_RED_EXPRESS', (6022, 18178, 1200, 1192)),
#  ('Lisbon_DARKGREEN_LOCAL',
#   'New York City_DARKGREEN_LOCAL',
#   (5429, 16398, 1200, 1191)),
#  ('Lisbon_DARKGREEN_EXPRESS',
#   'New York City_DARKGREEN_EXPRESS',
#   (5429, 16398, 1200, 1191)),
#  ('New York City_DARKGREEN_LOCAL',
#   'Lisbon_DARKGREEN_LOCAL',
#   (5429, 16398, 1200, 1191)),
#  ('New York City_DARKGREEN_EXPRESS',
#   'Lisbon_DARKGREEN_EXPRESS',
#   (5429, 16398, 1200, 1191)),
#  ('Bali_AQUA_EXPRESS', 'Melbourne_AQUA_EXPRESS', (5310, 16043, 1200, 1191)),
#  ('Melbourne_AQUA_EXPRESS', 'Bali_AQUA_EXPRESS', (5310, 16043, 1200, 1191)),
#  ('Boston_BRONZE_EXPRESS', 'London_BRONZE_EXPRESS', (5292, 15987, 1200, 1191)),
#  ('London_BRONZE_EXPRESS', 'Boston_BRONZE_EXPRESS', (5292, 15987, 1200, 1191)),
#  ('Dili_ORANGE_EXPRESS', 'Sydney_ORANGE_EXPRESS', (5200, 15711, 1200, 1191)),
#  ('Sydney_ORANGE_EXPRESS', 'Dili_ORANGE_EXPRESS', (5200, 15711, 1200, 1191))]

# %%
# create the graph!!

def create_graph(transfer_time):
    G = nx.DiGraph()

    travel_edges = [(station1+'_DEP', station2+'_ARR', stats[1]) for station1, station2, stats in station_durs]
    G.add_weighted_edges_from(travel_edges)

    # time at station
    detail_station_set = set([b for a in [(station1, station2) for station1, station2, stats in station_durs] for b in a])
    G.add_weighted_edges_from([(station+'_ARR', station+'_DEP', TIME_AT_STATION) for station in detail_station_set])

    for i, row in station_df.iterrows():
        station = row['station']
        lines = row['lines'].split(',')
        if row['line_num'] > 1:
            all_line_pairs = list(itertools.permutations(lines, 2))
            # transfer between lines
            if row['type'] == 'EXPRESS':
                for line1, line2 in all_line_pairs:
                    G.add_weighted_edges_from([(station+'_'+line1+'_LOCAL_ARR', station+'_'+line2+'_LOCAL_DEP', transfer_time)])
                    G.add_weighted_edges_from([(station+'_'+line1+'_EXPRESS_ARR', station+'_'+line2+'_EXPRESS_DEP', transfer_time)])
                    G.add_weighted_edges_from([(station+'_'+line1+'_LOCAL_ARR', station+'_'+line2+'_EXPRESS_DEP', transfer_time)])
                    G.add_weighted_edges_from([(station+'_'+line1+'_EXPRESS_ARR', station+'_'+line2+'_LOCAL_DEP', transfer_time)])
            else:
                for line1, line2 in all_line_pairs:
                    G.add_weighted_edges_from([(station+'_'+line1+'_LOCAL_ARR', station+'_'+line2+'_LOCAL_DEP', transfer_time)])
        # express-local transfer
        if row['type'] == 'EXPRESS':
            for line in lines:
                G.add_weighted_edges_from([(station+'_'+line+'_LOCAL_ARR', station+'_'+line+'_EXPRESS_DEP', transfer_time)])
                G.add_weighted_edges_from([(station+'_'+line+'_EXPRESS_ARR', station+'_'+line+'_LOCAL_DEP', transfer_time)])

    print('Num nodes', G.number_of_nodes())
    print('Num edges', G.number_of_edges())
    return G

G_speed = create_graph(TRANSFER_TIME_1)
G_transfer = create_graph(TRANSFER_TIME_2)

nx.write_adjlist(G_speed, )
# Out:
# Num nodes 1448
# Num edges 4272
# Num nodes 1448
# Num edges 4272

# %%
def s_to_hm(s):
    return str(s//3600) + 'h ' + str((s-3600*(s//3600))//60) + 'm' if s//3600 > 0 else str(s//60) + 'min'



def run_analysis(G, origin_st, dest_st, transfer_time):
    station_durs_dict = {(station1+'_DEP', station2+'_ARR'): {'distance': stats[0], 'duration': stats[1], 'avg_speed': stats[3]} for station1, station2, stats in station_durs}

    detailed_st_per_st = {}
    for detailed_st in detail_station_set:
        station, line, exploc = detailed_st.split('_')
        detailed_st_per_st[station] = detailed_st_per_st[station] + [detailed_st] if station in detailed_st_per_st else [detailed_st]

    origin_set = set([st + '_DEP' for st in detailed_st_per_st[origin_st]])
    dest_set = set([st + '_ARR' for st in detailed_st_per_st[dest_st]])

    best_segments = None
    best_dur = float('inf')
    best_transfers = None

    for dest_st in dest_set:
        dur, path = nx.multi_source_dijkstra(G, origin_set, dest_st)
        if dur < best_dur:
            segments, line_list, transfers = {}, [path[0].split('_')[1]], []
            beg_station = origin_st
            cum_duration = 0
            cum_distance = 0
            stops = []
            for i in range(len(path)-1):
                station1, line1, type1, deparr1 = path[i].split('_')
                station2, line2, type2, deparr2 = path[i+1].split('_')
                if deparr1 == 'DEP' and deparr2 == 'ARR': # travel dist
                    cum_duration += station_durs_dict[(path[i], path[i+1])]['duration']
                    cum_distance += station_durs_dict[(path[i], path[i+1])]['distance']
                    stops.append((station2, station_durs_dict[(path[i], path[i+1])]['duration'], station_durs_dict[(path[i], path[i+1])]['distance']))
                elif deparr1 == 'ARR' and deparr2 == 'DEP':
                    if line1 != line2 or type1 != type2:
                        end_station = station1
                        segments[(beg_station, end_station)] = {'type': 'travel', 'stops': stops, 'line': line1 + ' ' + type1, 'distance': cum_distance, 'duration': cum_duration}
                        beg_station = end_station
                        cum_distance, cum_duration, stops = 0, 0, []
                        transfers.append(station1)
                        if line1 != line2: # transfer between two lines
                            line_list.append(line2)
                            segments[(station1, station2)] = {'type': 'reg_transfer', 'lines': (line1 + ' ' + type1, line2 + ' ' + type2), 'distance': 0, 'duration': transfer_time}
                        elif type1 != type2: # local-exp transfer
                            segments[(station1, station2)] = {'type': 'le_transfer', 'lines': (line1 + ' ' + type1, line2 + ' ' + type2), 'distance': 0, 'duration': transfer_time}
                    else:
                        cum_duration += TIME_AT_STATION
                else:
                    print('whats going on')

            # add the last leg
            end_station = station2
            segments[(beg_station, end_station)] = {'type': 'travel', 'stops': stops, 'line': line1 + ' ' + type1, 'distance': cum_distance, 'duration': cum_duration}

            best_segments = segments
            best_dur = dur
            best_transfers = transfers


    counter = 0
    for segment in best_segments:
        station1, station2 = segment
        counter += 1
        if best_segments[segment]['type'] == 'travel':
            stops = best_segments[segment]['stops']
            print(str(counter), 'Take the', best_segments[segment]['line'], 'line from', station1, 'to', station2, '(' + str(best_segments[segment]['distance']) + 'km' + ' '  + s_to_hm(best_segments[segment]['duration']) + ')')
            for stop, dur, dist in stops:
                print('    ', stop, str(dist)+'km', s_to_hm(dur))
        else:
            print(str(counter), 'Transfer at', station1, 'from the', best_segments[segment]['lines'][0], 'line to the', best_segments[segment]['lines'][1], 'line')
    print()  
    print('Transfers:', len(transfers))
    print('Total time:', s_to_hm(best_dur - (transfer_time - TRANSFER_TIME_1)*len(transfers)))

# %%
origin_st = 'New York City'
dest_st = 'Nairobi'

origin_coords = (station_df.set_index('station').at[origin_st, 'lat'], station_df.set_index('station').at[origin_st, 'long'])
dest_coords = (station_df.set_index('station').at[dest_st, 'lat'], station_df.set_index('station').at[dest_st, 'long'])


print(origin_st, 'to', dest_st)
print('Straight line distance:', int(distance.distance(origin_coords, dest_coords).km), 'km')
print('By plane at 800kmh:', s_to_hm(int(3600*distance.distance(origin_coords, dest_coords).km/800)))
print()
print('Transfer time:', TRANSFER_TIME_1_M, 'minutes')
print('Time at station:', TIME_AT_STATION_M, 'minutes')
print('Train speed:', MAX_SPEED_KMH, 'kmh')

print('\n\n')
print('Prioritize speed')
run_analysis(G_speed, origin_st, dest_st, TRANSFER_TIME_1)

print('\n\n')
print('Prioritize less transfers')
run_analysis(G_transfer, origin_st, dest_st, TRANSFER_TIME_2)
# Out:
# New York City to Nairobi
# Straight line distance: 11843 km
# By plane at 800kmh: 14h 48m
#
# Transfer time: 30 minutes
# Time at station: 5 minutes
# Train speed: 1200 kmh
#
#
#
# Prioritize speed
# 1 Take the DARKGREEN LOCAL line from New York City to Cairo (9815km 8h 53m)
#      Lisbon 5429km 4h 33m
#      Madrid 504km 27min
#      Barcelona 506km 27min
#      Milan 727km 38min
#      Rome 476km 25min
#      Athens 1054km 54min
#      Cairo 1119km 57min
# 2 Transfer at Cairo from the DARKGREEN LOCAL line to the LIGHTGREEN EXPRESS line
# 3 Take the LIGHTGREEN EXPRESS line from Cairo to Addis Ababa (2990km 2h 38m)
#      Khartoum 1606km 1h 22m
#      Addis Ababa 1384km 1h 11m
# 4 Transfer at Addis Ababa from the LIGHTGREEN EXPRESS line to the BLUE LOCAL line
# 5 Take the BLUE LOCAL line from Addis Ababa to Nairobi (1159km 59min)
#      Nairobi 1159km 59min
#
# Transfers: 2
# Total time: 13h 31m
#
#
#
# Prioritize less transfers
# 1 Take the BRONZE EXPRESS line from New York City to Nairobi (16247km 14h 42m)
#      Boston 297km 16min
#      London 5292km 4h 26m
#      Paris 341km 18min
#      Barcelona 831km 43min
#      Casablanca 1222km 1h 2m
#      Bamako 2320km 1h 57m
#      Ouagadougou 704km 37min
#      Kano 1130km 58min
#      Bangui 1650km 1h 24m
#      Kampala 1957km 1h 39m
#      Nairobi 503km 27min
#
# Transfers: 0
# Total time: 14h 42m

# %%
by_region = station_df[['region', 'station']].groupby('region').count().reset_index().sort_values('station', ascending=False)
by_region
# Out:
#      region  station
# 2      Asia       93
# 1  Americas       62
# 0    Africa       61
# 3    Europe       51
# 4   Oceania       10

# %%
by_subregion = station_df[['region', 'sub_region', 'station']].groupby(['region', 'sub_region']).count().reset_index().sort_values('station', ascending=False)
by_subregion
# Out:
#       region                       sub_region  station
# 1     Africa               Sub-Saharan Africa       53
# 2   Americas  Latin America and the Caribbean       40
# 5       Asia                     Eastern Asia       28
# 7       Asia                    Southern Asia       23
# 3   Americas                 Northern America       22
# 8       Asia                     Western Asia       19
# 9     Europe                   Eastern Europe       19
# 6       Asia               South-eastern Asia       18
# 11    Europe                  Southern Europe       12
# 10    Europe                  Northern Europe       11
# 12    Europe                   Western Europe        9
# 0     Africa                  Northern Africa        8
# 13   Oceania        Australia and New Zealand        6
# 4       Asia                     Central Asia        5
# 14   Oceania                        Melanesia        4

# %%
by_country = station_df[['country_territory', 'station']].groupby('country_territory').count().reset_index().sort_values('station', ascending=False)
print('Total countries/territories:', by_country.shape[0])
by_country[by_country['station'] > 1]
# Out:
# Total countries/territories: 178
#                                      country_territory  station
# 32                                               China       17
# 169                           United States of America       16
# 73                                               India       11
# 134                                 Russian Federation        9
# 21                                              Brazil        6
# 28                                              Canada        6
# 74                                           Indonesia        4
# 6                                            Australia        4
# 81                                               Japan        4
# 123                                           Pakistan        3
# 105                                             Mexico        3
# 119                                            Nigeria        3
# 84                                               Kenya        2
# 27                                            Cameroon        2
# 36                   Congo, Democratic Republic of the        2
# 33                                            Colombia        2
# 79                                               Italy        2
# 158                                           Thailand        2
# 116                                        New Zealand        2
# 148                                              Spain        2
# 46                                               Egypt        2
# 146                                       South Africa        2
# 75                          Iran (Islamic Republic of)        2
# 157                       Tanzania, United Republic of        2
# 60                                             Germany        2
# 111                                            Myanmar        2
# 166                                            Ukraine        2
# 128                                        Philippines        2
# 173                                           Viet Nam        2
# 55                                              France        2
# 11                                          Bangladesh        2
# 168  United Kingdom of Great Britain and Northern I...        2
# 167                               United Arab Emirates        2
# 163                                             Turkey        2
# 18                    Bolivia (Plurinational State of)        2
# 137                                       Saudi Arabia        2
# 86                                  Korea, Republic of        2

# %%
    
get_time_from_dist(1)
# Out:
# (1, 36, 197, 98)

# %%
station_dict
# Out:
# {'Denver': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['Las Vegas_DARKGREEN', 'Chicago_DARKGREEN'],
#   'next_express_stations': ['Las Vegas_DARKGREEN', 'Chicago_DARKGREEN']},
#  'Skopje': {'lines': {'AQUA'},
#   'next_local_stations': ['Tirana_AQUA', 'Istanbul_AQUA'],
#   'next_express_stations': []},
#  'Berlin': {'lines': {'DARKGREEN', 'LILAC'},
#   'next_local_stations': ['Prague_LILAC',
#    'Copenhagen_LILAC',
#    'Amsterdam_DARKGREEN',
#    'Warsaw_DARKGREEN'],
#   'next_express_stations': ['Prague_LILAC',
#    'Copenhagen_LILAC',
#    'Amsterdam_DARKGREEN',
#    'Kyiv_DARKGREEN']},
#  'Panama City': {'lines': {'ORANGE'},
#   'next_local_stations': ['Medellin_ORANGE', 'San Jose_ORANGE'],
#   'next_express_stations': []},
#  'Lisbon': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['New York City_DARKGREEN', 'Madrid_DARKGREEN'],
#   'next_express_stations': ['New York City_DARKGREEN', 'Madrid_DARKGREEN']},
#  'Harbin': {'lines': {'ORANGE'},
#   'next_local_stations': ['Khabarovsk_ORANGE', 'Shenyang_ORANGE'],
#   'next_express_stations': ['Khabarovsk_ORANGE', 'Shenyang_ORANGE']},
#  'Yangon': {'lines': {'LIGHTGREEN', 'LILAC'},
#   'next_local_stations': ['Mandalay_LIGHTGREEN',
#    'Bangkok_LIGHTGREEN',
#    'Bangkok_LILAC',
#    'Dhaka_LILAC'],
#   'next_express_stations': ['Chittagong_LIGHTGREEN',
#    'Bangkok_LIGHTGREEN',
#    'Bangkok_LILAC',
#    'Dhaka_LILAC']},
#  'Mandalay': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Chittagong_LIGHTGREEN', 'Yangon_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Tianjin': {'lines': {'AQUA'},
#   'next_local_stations': ['Beijing_AQUA', 'Shanghai_AQUA', 'Dalian_AQUA'],
#   'next_express_stations': ['Beijing_AQUA', 'Shanghai_AQUA', 'Dalian_AQUA']},
#  'Irkutsk': {'lines': {'RED'},
#   'next_local_stations': ['Krasnoyarsk_RED',
#    'Ulaanbaatar_RED',
#    'Khabarovsk_RED'],
#   'next_express_stations': []},
#  'Suva': {'lines': {'ORANGE'},
#   'next_local_stations': ['Noumea_ORANGE'],
#   'next_express_stations': []},
#  'Phuket': {'lines': {'AQUA'},
#   'next_local_stations': ['Bangkok_AQUA', 'Kuala Lumpur_AQUA'],
#   'next_express_stations': []},
#  'Yerevan': {'lines': {'AQUA'},
#   'next_local_stations': ['Ankara_AQUA', 'Tbilisi_AQUA'],
#   'next_express_stations': []},
#  'Alexandria': {'lines': {'SILVER'},
#   'next_local_stations': ['Tripoli_SILVER', 'Cairo_SILVER'],
#   'next_express_stations': ['Tripoli_SILVER', 'Cairo_SILVER']},
#  'Dubai': {'lines': {'BLUE', 'BRONZE', 'LILAC', 'SILVER'},
#   'next_local_stations': ['Doha_BRONZE',
#    'Abu Dhabi_SILVER',
#    'Muscat_SILVER',
#    'Sanaa_BLUE',
#    'Doha_BLUE',
#    'Muscat_LILAC',
#    'Abu Dhabi_LILAC'],
#   'next_express_stations': ['Doha_BRONZE',
#    'Abu Dhabi_SILVER',
#    'Muscat_SILVER',
#    'Sanaa_BLUE',
#    'Doha_BLUE',
#    'Muscat_LILAC',
#    'Abu Dhabi_LILAC']},
#  'Lome': {'lines': {'BRONZE'},
#   'next_local_stations': ['Accra_BRONZE', 'Cotonou_BRONZE'],
#   'next_express_stations': []},
#  'Port Moresby': {'lines': {'ORANGE'},
#   'next_local_stations': ['Dili_ORANGE', 'Brisbane_ORANGE', 'Honiara_ORANGE'],
#   'next_express_stations': []},
#  'Zagreb': {'lines': {'AQUA', 'LILAC'},
#   'next_local_stations': ['Ljubljana_AQUA',
#    'Sarajevo_AQUA',
#    'Rome_LILAC',
#    'Vienna_LILAC'],
#   'next_express_stations': ['Paris_AQUA',
#    'Istanbul_AQUA',
#    'Rome_LILAC',
#    'Vienna_LILAC']},
#  'Auckland': {'lines': {'AQUA'},
#   'next_local_stations': ['Sydney_AQUA', 'Christchurch_AQUA'],
#   'next_express_stations': []},
#  'Mexico City': {'lines': {'ORANGE', 'PURPLE'},
#   'next_local_stations': ['Guatemala City_ORANGE',
#    'Guadalajara_ORANGE',
#    'Monterrey_PURPLE',
#    'Guatemala City_PURPLE'],
#   'next_express_stations': ['Guatemala City_ORANGE',
#    'Guadalajara_ORANGE',
#    'Monterrey_PURPLE',
#    'Guatemala City_PURPLE']},
#  'Jinan': {'lines': {'RED'},
#   'next_local_stations': ['Beijing_RED', 'Shanghai_RED'],
#   'next_express_stations': ['Beijing_RED', 'Shanghai_RED']},
#  'Ho Chi Minh City': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Phnom Penh_LIGHTGREEN', 'Singapore_LIGHTGREEN'],
#   'next_express_stations': ['Bangkok_LIGHTGREEN', 'Singapore_LIGHTGREEN']},
#  'Antananarivo': {'lines': {'BLUE'},
#   'next_local_stations': ['Moroni_BLUE', 'Saint-Denis_BLUE'],
#   'next_express_stations': []},
#  'Lahore': {'lines': {'BLUE', 'LIGHTGREEN'},
#   'next_local_stations': ['Islamabad_LIGHTGREEN',
#    'Delhi_LIGHTGREEN',
#    'Karachi_BLUE',
#    'Delhi_BLUE'],
#   'next_express_stations': ['Kabul_LIGHTGREEN',
#    'Delhi_LIGHTGREEN',
#    'Karachi_BLUE',
#    'Delhi_BLUE']},
#  'Hanoi': {'lines': {'AQUA'},
#   'next_local_stations': ['Macau_AQUA', 'Vientiane_AQUA'],
#   'next_express_stations': ['Macau_AQUA', 'Bangkok_AQUA']},
#  'Mumbai': {'lines': {'LILAC', 'NAVY', 'SILVER'},
#   'next_local_stations': ['Ahmadabad_SILVER',
#    'Pune_SILVER',
#    'Male_NAVY',
#    'Delhi_NAVY',
#    'Hyderabad_LILAC',
#    'Surat_LILAC'],
#   'next_express_stations': ['Ahmadabad_SILVER',
#    'Pune_SILVER',
#    'Mogadishu_NAVY',
#    'Delhi_NAVY',
#    'Hyderabad_LILAC',
#    'Surat_LILAC']},
#  'Athens': {'lines': {'DARKGREEN', 'LILAC'},
#   'next_local_stations': ['Cairo_LILAC',
#    'Istanbul_LILAC',
#    'Rome_LILAC',
#    'Rome_DARKGREEN',
#    'Cairo_DARKGREEN'],
#   'next_express_stations': ['Cairo_LILAC',
#    'Istanbul_LILAC',
#    'Rome_LILAC',
#    'Rome_DARKGREEN',
#    'Cairo_DARKGREEN']},
#  'Johannesburg': {'lines': {'BLUE', 'BRONZE'},
#   'next_local_stations': ['Gaborone_BRONZE', 'Maseru_BLUE', 'Mbabane_BLUE'],
#   'next_express_stations': ['Luanda_BRONZE',
#    'Cape Town_BLUE',
#    'Dar es Salaam_BLUE']},
#  'Chicago': {'lines': {'DARKGREEN', 'ORANGE'},
#   'next_local_stations': ['Seattle_ORANGE',
#    'Washington D.C._ORANGE',
#    'Denver_DARKGREEN',
#    'Toronto_DARKGREEN'],
#   'next_express_stations': ['Seattle_ORANGE',
#    'Washington D.C._ORANGE',
#    'Denver_DARKGREEN',
#    'Toronto_DARKGREEN']},
#  'Jakarta': {'lines': {'AQUA', 'LIGHTGREEN'},
#   'next_local_stations': ['Singapore_AQUA',
#    'Surabaya_AQUA',
#    'Singapore_LIGHTGREEN',
#    'Bali_LIGHTGREEN'],
#   'next_express_stations': ['Singapore_AQUA',
#    'Surabaya_AQUA',
#    'Singapore_LIGHTGREEN',
#    'Bali_LIGHTGREEN']},
#  'Maseru': {'lines': {'BLUE'},
#   'next_local_stations': ['Cape Town_BLUE', 'Johannesburg_BLUE'],
#   'next_express_stations': []},
#  'Shenzhen': {'lines': {'ORANGE'},
#   'next_local_stations': ['Guangzhou_ORANGE', 'Hong Kong_ORANGE'],
#   'next_express_stations': ['Guangzhou_ORANGE', 'Hong Kong_ORANGE']},
#  'Mwanza': {'lines': {'NAVY'},
#   'next_local_stations': ['Bangui_NAVY', 'Nairobi_NAVY'],
#   'next_express_stations': []},
#  'Chengdu': {'lines': {'DARKGREEN', 'NAVY'},
#   'next_local_stations': ['Thimphu_NAVY',
#    'Chongqing_NAVY',
#    "Xi'an_DARKGREEN",
#    'Bangkok_DARKGREEN'],
#   'next_express_stations': ['Delhi_NAVY',
#    'Chongqing_NAVY',
#    "Xi'an_DARKGREEN",
#    'Bangkok_DARKGREEN']},
#  'Bratislava': {'lines': {'BRONZE'},
#   'next_local_stations': ['Prague_BRONZE', 'Budapest_BRONZE'],
#   'next_express_stations': []},
#  'Milan': {'lines': {'DARKGREEN', 'RED'},
#   'next_local_stations': ['Rome_RED',
#    'Monaco_RED',
#    'Barcelona_DARKGREEN',
#    'Rome_DARKGREEN'],
#   'next_express_stations': ['Rome_RED',
#    'Paris_RED',
#    'Barcelona_DARKGREEN',
#    'Rome_DARKGREEN']},
#  'Brazzaville': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Luanda_LIGHTGREEN', 'Kinshasa_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Laayoune': {'lines': {'BRONZE'},
#   'next_local_stations': ['Casablanca_BRONZE', 'Nouakchott_BRONZE'],
#   'next_express_stations': []},
#  'Tallinn': {'lines': {'LILAC'},
#   'next_local_stations': ['Riga_LILAC', 'Helsinki_LILAC'],
#   'next_express_stations': []},
#  'Nagpur': {'lines': {'BLUE'},
#   'next_local_stations': ['Delhi_BLUE', 'Hyderabad_BLUE'],
#   'next_express_stations': ['Delhi_BLUE', 'Hyderabad_BLUE']},
#  'Lyon': {'lines': {'RED'},
#   'next_local_stations': ['Monaco_RED', 'Paris_RED'],
#   'next_express_stations': []},
#  'Guatemala City': {'lines': {'ORANGE', 'PURPLE'},
#   'next_local_stations': ['San Salvador_ORANGE',
#    'Mexico City_ORANGE',
#    'Mexico City_PURPLE',
#    'Belize City_PURPLE'],
#   'next_express_stations': ['Medellin_ORANGE',
#    'Mexico City_ORANGE',
#    'Mexico City_PURPLE',
#    'Kingston_PURPLE']},
#  'Sanaa': {'lines': {'BLUE'},
#   'next_local_stations': ['Djibouti_BLUE', 'Dubai_BLUE'],
#   'next_express_stations': ['Addis Ababa_BLUE', 'Dubai_BLUE']},
#  'Washington D.C.': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['Chicago_ORANGE',
#    'New York City_ORANGE',
#    'Atlanta_BRONZE',
#    'New York City_BRONZE'],
#   'next_express_stations': ['Chicago_ORANGE',
#    'New York City_ORANGE',
#    'Atlanta_BRONZE',
#    'New York City_BRONZE']},
#  'Monaco': {'lines': {'RED'},
#   'next_local_stations': ['Milan_RED', 'Lyon_RED'],
#   'next_express_stations': []},
#  'Dakar': {'lines': {'BRONZE', 'NAVY'},
#   'next_local_stations': ['Nouakchott_BRONZE', 'Banjul_BRONZE', 'Bamako_NAVY'],
#   'next_express_stations': ['Casablanca_BRONZE',
#    'Abidjan_BRONZE',
#    'Bamako_NAVY']},
#  'Niamey': {'lines': {'BRONZE'},
#   'next_local_stations': ['Ouagadougou_BRONZE', 'Kano_BRONZE'],
#   'next_express_stations': []},
#  'Tegucigalpa': {'lines': {'ORANGE'},
#   'next_local_stations': ['Managua_ORANGE', 'San Salvador_ORANGE'],
#   'next_express_stations': []},
#  'Riyadh': {'lines': {'LILAC', 'SILVER'},
#   'next_local_stations': ['Amman_SILVER',
#    'Abu Dhabi_SILVER',
#    'Abu Dhabi_LILAC',
#    'Jeddah_LILAC'],
#   'next_express_stations': ['Amman_SILVER',
#    'Abu Dhabi_SILVER',
#    'Abu Dhabi_LILAC',
#    'Jeddah_LILAC']},
#  'Georgetown': {'lines': {'BRONZE'},
#   'next_local_stations': ['Paramaribo_BRONZE', 'Port of Spain_BRONZE'],
#   'next_express_stations': []},
#  'Buenos Aires': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['Montevideo_ORANGE',
#    'Santiago_ORANGE',
#    'Santiago_BRONZE',
#    'Montevideo_BRONZE'],
#   'next_express_stations': ['Montevideo_ORANGE',
#    'Santiago_ORANGE',
#    'Santiago_BRONZE',
#    'Montevideo_BRONZE']},
#  'Douala': {'lines': {'BRONZE'},
#   'next_local_stations': ['Lagos_BRONZE', 'Bata_BRONZE'],
#   'next_express_stations': []},
#  'Prague': {'lines': {'BRONZE', 'LILAC'},
#   'next_local_stations': ['Frankfurt_BRONZE',
#    'Bratislava_BRONZE',
#    'Vienna_LILAC',
#    'Berlin_LILAC'],
#   'next_express_stations': ['Frankfurt_BRONZE',
#    'Istanbul_BRONZE',
#    'Vienna_LILAC',
#    'Berlin_LILAC']},
#  'Los Angeles': {'lines': {'DARKGREEN', 'ORANGE'},
#   'next_local_stations': ['Guadalajara_ORANGE',
#    'San Francisco_ORANGE',
#    'Phoenix_ORANGE',
#    'Honolulu_DARKGREEN',
#    'Las Vegas_DARKGREEN'],
#   'next_express_stations': ['Guadalajara_ORANGE',
#    'San Francisco_ORANGE',
#    'Phoenix_ORANGE',
#    'Tokyo_DARKGREEN',
#    'Las Vegas_DARKGREEN']},
#  'Saint Petersburg': {'lines': {'LILAC', 'RED'},
#   'next_local_stations': ['Helsinki_RED',
#    'Moscow_RED',
#    'Helsinki_LILAC',
#    'Moscow_LILAC'],
#   'next_express_stations': ['Helsinki_RED',
#    'Moscow_RED',
#    'Helsinki_LILAC',
#    'Moscow_LILAC']},
#  'Nouakchott': {'lines': {'BRONZE'},
#   'next_local_stations': ['Laayoune_BRONZE', 'Dakar_BRONZE', 'Bamako_BRONZE'],
#   'next_express_stations': []},
#  'Vilnius': {'lines': {'LILAC'},
#   'next_local_stations': ['Minsk_LILAC', 'Riga_LILAC'],
#   'next_express_stations': []},
#  'Dallas': {'lines': {'ORANGE'},
#   'next_local_stations': ['Phoenix_ORANGE', 'Houston_ORANGE'],
#   'next_express_stations': ['Phoenix_ORANGE', 'Houston_ORANGE']},
#  'Abidjan': {'lines': {'BRONZE'},
#   'next_local_stations': ['Monrovia_BRONZE', 'Accra_BRONZE'],
#   'next_express_stations': ['Dakar_BRONZE', 'Accra_BRONZE']},
#  'Islamabad': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Kabul_LIGHTGREEN', 'Lahore_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Las Vegas': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['Los Angeles_DARKGREEN', 'Denver_DARKGREEN'],
#   'next_express_stations': ['Los Angeles_DARKGREEN', 'Denver_DARKGREEN']},
#  'Moscow': {'lines': {'DARKGREEN', 'LILAC', 'RED'},
#   'next_local_stations': ['Saint Petersburg_RED',
#    'Kazan_RED',
#    'Saint Petersburg_LILAC',
#    'Sevastopol_DARKGREEN'],
#   'next_express_stations': ['Saint Petersburg_RED',
#    'Beijing_RED',
#    'Khabarovsk_RED',
#    'Saint Petersburg_LILAC',
#    'Kyiv_DARKGREEN']},
#  'Bangkok': {'lines': {'AQUA', 'DARKGREEN', 'LIGHTGREEN', 'LILAC'},
#   'next_local_stations': ['Vientiane_AQUA',
#    'Phuket_AQUA',
#    'Yangon_LIGHTGREEN',
#    'Phnom Penh_LIGHTGREEN',
#    'Yangon_LILAC',
#    'Chengdu_DARKGREEN'],
#   'next_express_stations': ['Hanoi_AQUA',
#    'Kuala Lumpur_AQUA',
#    'Yangon_LIGHTGREEN',
#    'Ho Chi Minh City_LIGHTGREEN',
#    'Manila_LIGHTGREEN',
#    'Yangon_LILAC',
#    'Chengdu_DARKGREEN']},
#  'Anchorage': {'lines': {'ORANGE'},
#   'next_local_stations': ['Vancouver_ORANGE', 'Khabarovsk_ORANGE'],
#   'next_express_stations': []},
#  'Hyderabad': {'lines': {'BLUE', 'LILAC'},
#   'next_local_stations': ['Nagpur_BLUE',
#    'Bangalore_BLUE',
#    'Kolkata_LILAC',
#    'Mumbai_LILAC'],
#   'next_express_stations': ['Nagpur_BLUE',
#    'Bangalore_BLUE',
#    'Kolkata_LILAC',
#    'Mumbai_LILAC']},
#  'Quito': {'lines': {'ORANGE', 'RED'},
#   'next_local_stations': ['Lima_ORANGE',
#    'Bogota_ORANGE',
#    'Bogota_RED',
#    'Lima_RED'],
#   'next_express_stations': ['Lima_ORANGE',
#    'Bogota_ORANGE',
#    'Bogota_RED',
#    'Lima_RED']},
#  'Belo Horizonte': {'lines': {'BRONZE'},
#   'next_local_stations': ['Rio de Janeiro_BRONZE', 'Brasilia_BRONZE'],
#   'next_express_stations': ['Rio de Janeiro_BRONZE', 'Brasilia_BRONZE']},
#  'Lubumbashi': {'lines': {'BRONZE'},
#   'next_local_stations': ['Luanda_BRONZE', 'Lusaka_BRONZE'],
#   'next_express_stations': []},
#  'Fort-de-France': {'lines': {'PURPLE'},
#   'next_local_stations': ['Basse-Terre_PURPLE', 'Bridgetown_PURPLE'],
#   'next_express_stations': []},
#  'Abuja': {'lines': {'RED'},
#   'next_local_stations': ['Lagos_RED', 'Kano_RED'],
#   'next_express_stations': []},
#  'Tbilisi': {'lines': {'AQUA'},
#   'next_local_stations': ['Yerevan_AQUA', 'Baku_AQUA'],
#   'next_express_stations': []},
#  'Medellin': {'lines': {'ORANGE'},
#   'next_local_stations': ['Bogota_ORANGE', 'Panama City_ORANGE'],
#   'next_express_stations': ['Bogota_ORANGE', 'Guatemala City_ORANGE']},
#  'Doha': {'lines': {'BLUE', 'BRONZE'},
#   'next_local_stations': ['Amman_BRONZE',
#    'Dubai_BRONZE',
#    'Dubai_BLUE',
#    'Manama_BLUE'],
#   'next_express_stations': ['Amman_BRONZE',
#    'Dubai_BRONZE',
#    'Dubai_BLUE',
#    'Kuwait City_BLUE']},
#  'Luanda': {'lines': {'BRONZE', 'LIGHTGREEN'},
#   'next_local_stations': ['Libreville_BRONZE',
#    'Lubumbashi_BRONZE',
#    'Windhoek_LIGHTGREEN',
#    'Brazzaville_LIGHTGREEN'],
#   'next_express_stations': ['Lagos_BRONZE',
#    'Johannesburg_BRONZE',
#    'Cape Town_LIGHTGREEN',
#    'Kinshasa_LIGHTGREEN']},
#  'Nassau': {'lines': {'ORANGE'},
#   'next_local_stations': ['Miami_ORANGE'],
#   'next_express_stations': []},
#  'Damascus': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Beirut_LIGHTGREEN', 'Baghdad_LIGHTGREEN'],
#   'next_express_stations': ['Beirut_LIGHTGREEN', 'Baghdad_LIGHTGREEN']},
#  'Houston': {'lines': {'ORANGE', 'PURPLE'},
#   'next_local_stations': ['Dallas_ORANGE',
#    'Miami_ORANGE',
#    'Atlanta_PURPLE',
#    'Monterrey_PURPLE'],
#   'next_express_stations': ['Dallas_ORANGE',
#    'Miami_ORANGE',
#    'Atlanta_PURPLE',
#    'Monterrey_PURPLE']},
#  'Cape Town': {'lines': {'BLUE', 'LIGHTGREEN'},
#   'next_local_stations': ['Windhoek_LIGHTGREEN', 'Maseru_BLUE'],
#   'next_express_stations': ['Luanda_LIGHTGREEN', 'Johannesburg_BLUE']},
#  'Conakry': {'lines': {'BRONZE'},
#   'next_local_stations': ['Bissau_BRONZE', 'Freetown_BRONZE'],
#   'next_express_stations': []},
#  'Madrid': {'lines': {'DARKGREEN', 'SILVER'},
#   'next_local_stations': ['London_SILVER',
#    'Casablanca_SILVER',
#    'Lisbon_DARKGREEN',
#    'Barcelona_DARKGREEN'],
#   'next_express_stations': ['London_SILVER',
#    'Casablanca_SILVER',
#    'Lisbon_DARKGREEN',
#    'Barcelona_DARKGREEN']},
#  'Asmara': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Addis Ababa_LIGHTGREEN', 'Khartoum_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Sao Paulo': {'lines': {'BRONZE', 'ORANGE', 'RED'},
#   'next_local_stations': ['Rio de Janeiro_ORANGE',
#    'Montevideo_ORANGE',
#    'Asuncion_RED',
#    'Rio de Janeiro_RED',
#    'Montevideo_BRONZE',
#    'Rio de Janeiro_BRONZE'],
#   'next_express_stations': ['Rio de Janeiro_ORANGE',
#    'Montevideo_ORANGE',
#    'La Paz_RED',
#    'Rio de Janeiro_RED',
#    'Montevideo_BRONZE',
#    'Rio de Janeiro_BRONZE']},
#  'New York City': {'lines': {'BRONZE', 'DARKGREEN', 'ORANGE', 'PURPLE'},
#   'next_local_stations': ['Washington D.C._ORANGE',
#    'Boston_ORANGE',
#    'Montreal_PURPLE',
#    'Atlanta_PURPLE',
#    'Washington D.C._BRONZE',
#    'Boston_BRONZE',
#    'Toronto_DARKGREEN',
#    'Lisbon_DARKGREEN'],
#   'next_express_stations': ['Washington D.C._ORANGE',
#    'Boston_ORANGE',
#    'Montreal_PURPLE',
#    'Atlanta_PURPLE',
#    'Washington D.C._BRONZE',
#    'Boston_BRONZE',
#    'Toronto_DARKGREEN',
#    'Lisbon_DARKGREEN']},
#  'Ljubljana': {'lines': {'AQUA'},
#   'next_local_stations': ['Zurich_AQUA', 'Zagreb_AQUA'],
#   'next_express_stations': []},
#  'Male': {'lines': {'NAVY'},
#   'next_local_stations': ['Mogadishu_NAVY', 'Mumbai_NAVY'],
#   'next_express_stations': []},
#  'Rome': {'lines': {'DARKGREEN', 'LILAC', 'RED'},
#   'next_local_stations': ['Tunis_RED',
#    'Milan_RED',
#    'Athens_LILAC',
#    'Zagreb_LILAC',
#    'Milan_DARKGREEN',
#    'Athens_DARKGREEN'],
#   'next_express_stations': ['Tunis_RED',
#    'Milan_RED',
#    'Athens_LILAC',
#    'Zagreb_LILAC',
#    'Milan_DARKGREEN',
#    'Athens_DARKGREEN']},
#  'Pune': {'lines': {'SILVER'},
#   'next_local_stations': ['Mumbai_SILVER', 'Bangalore_SILVER'],
#   'next_express_stations': ['Mumbai_SILVER', 'Bangalore_SILVER']},
#  'Ulaanbaatar': {'lines': {'RED'},
#   'next_local_stations': ['Irkutsk_RED', 'Beijing_RED'],
#   'next_express_stations': []},
#  'Manama': {'lines': {'BLUE'},
#   'next_local_stations': ['Doha_BLUE', 'Kuwait City_BLUE'],
#   'next_express_stations': []},
#  'Bangui': {'lines': {'BRONZE', 'NAVY'},
#   'next_local_stations': ["N'Djamena_BRONZE",
#    'Juba_BRONZE',
#    'Yaounde_NAVY',
#    'Mwanza_NAVY'],
#   'next_express_stations': ['Kano_BRONZE',
#    'Kampala_BRONZE',
#    'Lagos_NAVY',
#    'Nairobi_NAVY']},
#  'Budapest': {'lines': {'BRONZE'},
#   'next_local_stations': ['Bratislava_BRONZE', 'Belgrade_BRONZE'],
#   'next_express_stations': []},
#  'Sapporo': {'lines': {'RED'},
#   'next_local_stations': ['Vladivostok_RED', 'Tokyo_RED'],
#   'next_express_stations': ['Khabarovsk_RED', 'Tokyo_RED']},
#  'Warsaw': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['Berlin_DARKGREEN', 'Kyiv_DARKGREEN'],
#   'next_express_stations': []},
#  'Tunis': {'lines': {'RED', 'SILVER'},
#   'next_local_stations': ['Kano_RED',
#    'Rome_RED',
#    'Algiers_SILVER',
#    'Tripoli_SILVER'],
#   'next_express_stations': ['Kano_RED',
#    'Rome_RED',
#    'Algiers_SILVER',
#    'Tripoli_SILVER']},
#  'Atlanta': {'lines': {'BRONZE', 'PURPLE'},
#   'next_local_stations': ['New York City_PURPLE',
#    'Houston_PURPLE',
#    'Miami_BRONZE',
#    'Washington D.C._BRONZE'],
#   'next_express_stations': ['New York City_PURPLE',
#    'Houston_PURPLE',
#    'Miami_BRONZE',
#    'Washington D.C._BRONZE']},
#  'Bata': {'lines': {'BRONZE'},
#   'next_local_stations': ['Douala_BRONZE', 'Libreville_BRONZE'],
#   'next_express_stations': []},
#  'Novosibirsk': {'lines': {'RED'},
#   'next_local_stations': ['Yekaterinburg_RED', 'Krasnoyarsk_RED'],
#   'next_express_stations': []},
#  'Mombasa': {'lines': {'BLUE'},
#   'next_local_stations': ['Dar es Salaam_BLUE', 'Nairobi_BLUE'],
#   'next_express_stations': []},
#  'Frankfurt': {'lines': {'BRONZE'},
#   'next_local_stations': ['Brussels_BRONZE', 'Prague_BRONZE'],
#   'next_express_stations': ['Brussels_BRONZE', 'Prague_BRONZE']},
#  'Kigali': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Bujumbura_LIGHTGREEN', 'Kampala_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Sanya': {'lines': {'RED'},
#   'next_local_stations': ['Macau_RED'],
#   'next_express_stations': []},
#  'Kathmandu': {'lines': {'NAVY'},
#   'next_local_stations': ['Delhi_NAVY', 'Thimphu_NAVY'],
#   'next_express_stations': []},
#  'San Francisco': {'lines': {'ORANGE'},
#   'next_local_stations': ['Los Angeles_ORANGE', 'Seattle_ORANGE'],
#   'next_express_stations': ['Los Angeles_ORANGE', 'Seattle_ORANGE']},
#  'Cairo': {'lines': {'DARKGREEN', 'LIGHTGREEN', 'LILAC', 'SILVER'},
#   'next_local_stations': ['Alexandria_SILVER',
#    'Jerusalem_SILVER',
#    'Khartoum_LIGHTGREEN',
#    'Jerusalem_LIGHTGREEN',
#    'Jeddah_LILAC',
#    'Athens_LILAC',
#    'Athens_DARKGREEN'],
#   'next_express_stations': ['Alexandria_SILVER',
#    'Jerusalem_SILVER',
#    'Khartoum_LIGHTGREEN',
#    'Jerusalem_LIGHTGREEN',
#    'Jeddah_LILAC',
#    'Athens_LILAC',
#    'Athens_DARKGREEN']},
#  'Zurich': {'lines': {'AQUA'},
#   'next_local_stations': ['Paris_AQUA', 'Ljubljana_AQUA'],
#   'next_express_stations': []},
#  'Dublin': {'lines': {'BRONZE'},
#   'next_local_stations': ['Boston_BRONZE', 'London_BRONZE'],
#   'next_express_stations': []},
#  'Busan': {'lines': {'AQUA', 'NAVY'},
#   'next_local_stations': ['Seoul_AQUA',
#    'Fukuoka_AQUA',
#    'Seoul_NAVY',
#    'Fukuoka_NAVY'],
#   'next_express_stations': ['Seoul_AQUA',
#    'Fukuoka_AQUA',
#    'Seoul_NAVY',
#    'Fukuoka_NAVY']},
#  'Caracas': {'lines': {'BRONZE', 'RED'},
#   'next_local_stations': ['Bogota_RED',
#    'Port of Spain_BRONZE',
#    'Santo Domingo_BRONZE'],
#   'next_express_stations': ['Bogota_RED',
#    'Port of Spain_BRONZE',
#    'Santo Domingo_BRONZE']},
#  'Juba': {'lines': {'BRONZE'},
#   'next_local_stations': ['Bangui_BRONZE', 'Kampala_BRONZE'],
#   'next_express_stations': []},
#  'Toronto': {'lines': {'DARKGREEN', 'PURPLE'},
#   'next_local_stations': ['Winnipeg_PURPLE',
#    'Ottawa_PURPLE',
#    'Chicago_DARKGREEN',
#    'New York City_DARKGREEN'],
#   'next_express_stations': ['Vancouver_PURPLE',
#    'Montreal_PURPLE',
#    'Chicago_DARKGREEN',
#    'New York City_DARKGREEN']},
#  'Calgary': {'lines': {'PURPLE'},
#   'next_local_stations': ['Vancouver_PURPLE', 'Winnipeg_PURPLE'],
#   'next_express_stations': []},
#  'Dalian': {'lines': {'AQUA'},
#   'next_local_stations': ['Tianjin_AQUA', 'Seoul_AQUA'],
#   'next_express_stations': ['Tianjin_AQUA', 'Seoul_AQUA']},
#  'Vancouver': {'lines': {'ORANGE', 'PURPLE'},
#   'next_local_stations': ['Seattle_ORANGE',
#    'Anchorage_ORANGE',
#    'Calgary_PURPLE'],
#   'next_express_stations': ['Seattle_ORANGE',
#    'Khabarovsk_ORANGE',
#    'Toronto_PURPLE']},
#  'Sevastopol': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['Kyiv_DARKGREEN', 'Moscow_DARKGREEN'],
#   'next_express_stations': []},
#  'Paramaribo': {'lines': {'BRONZE'},
#   'next_local_stations': ['Cayenne_BRONZE', 'Georgetown_BRONZE'],
#   'next_express_stations': []},
#  'Mogadishu': {'lines': {'LIGHTGREEN', 'NAVY'},
#   'next_local_stations': ['Nairobi_NAVY',
#    'Male_NAVY',
#    'Nairobi_LIGHTGREEN',
#    'Addis Ababa_LIGHTGREEN'],
#   'next_express_stations': ['Nairobi_NAVY',
#    'Mumbai_NAVY',
#    'Nairobi_LIGHTGREEN',
#    'Addis Ababa_LIGHTGREEN']},
#  'Honiara': {'lines': {'ORANGE'},
#   'next_local_stations': ['Port Moresby_ORANGE', 'Noumea_ORANGE'],
#   'next_express_stations': []},
#  'Nairobi': {'lines': {'BLUE', 'BRONZE', 'LIGHTGREEN', 'NAVY'},
#   'next_local_stations': ['Kampala_BRONZE',
#    'Mwanza_NAVY',
#    'Mogadishu_NAVY',
#    'Kampala_LIGHTGREEN',
#    'Mogadishu_LIGHTGREEN',
#    'Mombasa_BLUE',
#    'Addis Ababa_BLUE'],
#   'next_express_stations': ['Kampala_BRONZE',
#    'Bangui_NAVY',
#    'Mogadishu_NAVY',
#    'Kampala_LIGHTGREEN',
#    'Mogadishu_LIGHTGREEN',
#    'Dar es Salaam_BLUE',
#    'Addis Ababa_BLUE']},
#  'Lilongwe': {'lines': {'BLUE'},
#   'next_local_stations': ['Harare_BLUE', 'Dar es Salaam_BLUE'],
#   'next_express_stations': []},
#  'Yekaterinburg': {'lines': {'RED'},
#   'next_local_stations': ['Kazan_RED', 'Novosibirsk_RED'],
#   'next_express_stations': []},
#  'Helsinki': {'lines': {'LILAC', 'RED'},
#   'next_local_stations': ['Stockholm_RED',
#    'Saint Petersburg_RED',
#    'Tallinn_LILAC',
#    'Saint Petersburg_LILAC'],
#   'next_express_stations': ['Copenhagen_RED',
#    'Saint Petersburg_RED',
#    'Kyiv_LILAC',
#    'Saint Petersburg_LILAC']},
#  'San Salvador': {'lines': {'ORANGE'},
#   'next_local_stations': ['Tegucigalpa_ORANGE', 'Guatemala City_ORANGE'],
#   'next_express_stations': []},
#  'Sydney': {'lines': {'AQUA', 'ORANGE'},
#   'next_local_stations': ['Brisbane_ORANGE',
#    'Melbourne_ORANGE',
#    'Melbourne_AQUA',
#    'Auckland_AQUA'],
#   'next_express_stations': ['Dili_ORANGE',
#    'Melbourne_ORANGE',
#    'Melbourne_AQUA']},
#  'Jeddah': {'lines': {'LILAC'},
#   'next_local_stations': ['Riyadh_LILAC', 'Cairo_LILAC'],
#   'next_express_stations': ['Riyadh_LILAC', 'Cairo_LILAC']},
#  'Brussels': {'lines': {'BRONZE', 'RED'},
#   'next_local_stations': ['Paris_RED',
#    'Amsterdam_RED',
#    'London_BRONZE',
#    'Frankfurt_BRONZE'],
#   'next_express_stations': ['Paris_RED',
#    'Amsterdam_RED',
#    'London_BRONZE',
#    'Frankfurt_BRONZE']},
#  'Reykjavik': {'lines': {'AQUA'},
#   'next_local_stations': ['Glasgow_AQUA'],
#   'next_express_stations': []},
#  'Copenhagen': {'lines': {'LILAC', 'RED'},
#   'next_local_stations': ['Amsterdam_RED', 'Oslo_RED', 'Berlin_LILAC'],
#   'next_express_stations': ['Amsterdam_RED', 'Helsinki_RED', 'Berlin_LILAC']},
#  'Phnom Penh': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Bangkok_LIGHTGREEN',
#    'Ho Chi Minh City_LIGHTGREEN',
#    'Manila_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Melbourne': {'lines': {'AQUA', 'ORANGE'},
#   'next_local_stations': ['Sydney_ORANGE', 'Perth_AQUA', 'Sydney_AQUA'],
#   'next_express_stations': ['Sydney_ORANGE', 'Bali_AQUA', 'Sydney_AQUA']},
#  'Monrovia': {'lines': {'BRONZE'},
#   'next_local_stations': ['Freetown_BRONZE', 'Abidjan_BRONZE'],
#   'next_express_stations': []},
#  'Tehran': {'lines': {'AQUA', 'BLUE', 'LIGHTGREEN'},
#   'next_local_stations': ['Baku_AQUA',
#    'Ashgabat_AQUA',
#    'Baghdad_LIGHTGREEN',
#    'Mashhad_LIGHTGREEN',
#    'Kuwait City_BLUE',
#    'Karachi_BLUE'],
#   'next_express_stations': ['Baku_AQUA',
#    'Tashkent_AQUA',
#    'Baghdad_LIGHTGREEN',
#    'Mashhad_LIGHTGREEN',
#    'Kuwait City_BLUE',
#    'Karachi_BLUE']},
#  'Krasnoyarsk': {'lines': {'RED'},
#   'next_local_stations': ['Novosibirsk_RED', 'Irkutsk_RED'],
#   'next_express_stations': []},
#  'Shenyang': {'lines': {'ORANGE', 'SILVER'},
#   'next_local_stations': ['Harbin_ORANGE',
#    'Beijing_ORANGE',
#    'Pyongyang_SILVER'],
#   'next_express_stations': ['Harbin_ORANGE',
#    'Beijing_ORANGE',
#    'Pyongyang_SILVER']},
#  'Kano': {'lines': {'BRONZE', 'RED'},
#   'next_local_stations': ['Abuja_RED',
#    'Tunis_RED',
#    'Niamey_BRONZE',
#    "N'Djamena_BRONZE"],
#   'next_express_stations': ['Lagos_RED',
#    'Tunis_RED',
#    'Ouagadougou_BRONZE',
#    'Bangui_BRONZE']},
#  'San Juan': {'lines': {'PURPLE'},
#   'next_local_stations': ['Santo Domingo_PURPLE', 'Basse-Terre_PURPLE'],
#   'next_express_stations': []},
#  'Ahmadabad': {'lines': {'LILAC', 'SILVER'},
#   'next_local_stations': ['Surat_SILVER',
#    'Mumbai_SILVER',
#    'Surat_LILAC',
#    'Karachi_LILAC'],
#   'next_express_stations': ['Surat_SILVER',
#    'Mumbai_SILVER',
#    'Surat_LILAC',
#    'Karachi_LILAC']},
#  'Hangzhou': {'lines': {'AQUA', 'RED'},
#   'next_local_stations': ['Shanghai_RED',
#    'Taipei_RED',
#    'Shanghai_AQUA',
#    'Taipei_AQUA'],
#   'next_express_stations': ['Shanghai_RED',
#    'Taipei_RED',
#    'Shanghai_AQUA',
#    'Taipei_AQUA']},
#  'Dushanbe': {'lines': {'AQUA'},
#   'next_local_stations': ['Ashgabat_AQUA', 'Tashkent_AQUA'],
#   'next_express_stations': []},
#  'Seattle': {'lines': {'ORANGE'},
#   'next_local_stations': ['San Francisco_ORANGE',
#    'Vancouver_ORANGE',
#    'Chicago_ORANGE'],
#   'next_express_stations': ['San Francisco_ORANGE',
#    'Vancouver_ORANGE',
#    'Chicago_ORANGE']},
#  'Windhoek': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Cape Town_LIGHTGREEN', 'Luanda_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Noumea': {'lines': {'ORANGE'},
#   'next_local_stations': ['Honiara_ORANGE', 'Suva_ORANGE'],
#   'next_express_stations': []},
#  'Davao': {'lines': {'ORANGE'},
#   'next_local_stations': ['Manila_ORANGE', 'Dili_ORANGE'],
#   'next_express_stations': []},
#  'Ottawa': {'lines': {'PURPLE'},
#   'next_local_stations': ['Toronto_PURPLE', 'Montreal_PURPLE'],
#   'next_express_stations': []},
#  'Tirana': {'lines': {'AQUA'},
#   'next_local_stations': ['Sarajevo_AQUA', 'Skopje_AQUA'],
#   'next_express_stations': []},
#  'Kampala': {'lines': {'BRONZE', 'LIGHTGREEN'},
#   'next_local_stations': ['Juba_BRONZE',
#    'Nairobi_BRONZE',
#    'Kigali_LIGHTGREEN',
#    'Nairobi_LIGHTGREEN'],
#   'next_express_stations': ['Bangui_BRONZE',
#    'Nairobi_BRONZE',
#    'Kinshasa_LIGHTGREEN',
#    'Nairobi_LIGHTGREEN']},
#  'Bali': {'lines': {'AQUA', 'LIGHTGREEN'},
#   'next_local_stations': ['Surabaya_AQUA',
#    'Perth_AQUA',
#    'Jakarta_LIGHTGREEN',
#    'Dili_LIGHTGREEN'],
#   'next_express_stations': ['Surabaya_AQUA',
#    'Melbourne_AQUA',
#    'Jakarta_LIGHTGREEN',
#    'Dili_LIGHTGREEN']},
#  'Dhaka': {'lines': {'LIGHTGREEN', 'LILAC'},
#   'next_local_stations': ['Lucknow_LIGHTGREEN',
#    'Chittagong_LIGHTGREEN',
#    'Yangon_LILAC',
#    'Kolkata_LILAC'],
#   'next_express_stations': ['Lucknow_LIGHTGREEN',
#    'Chittagong_LIGHTGREEN',
#    'Yangon_LILAC',
#    'Kolkata_LILAC']},
#  'Montevideo': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['Sao Paulo_ORANGE',
#    'Buenos Aires_ORANGE',
#    'Buenos Aires_BRONZE',
#    'Sao Paulo_BRONZE'],
#   'next_express_stations': ['Sao Paulo_ORANGE',
#    'Buenos Aires_ORANGE',
#    'Buenos Aires_BRONZE',
#    'Sao Paulo_BRONZE']},
#  'Yaounde': {'lines': {'NAVY'},
#   'next_local_stations': ['Lagos_NAVY', 'Bangui_NAVY'],
#   'next_express_stations': []},
#  'Basse-Terre': {'lines': {'PURPLE'},
#   'next_local_stations': ['San Juan_PURPLE', 'Fort-de-France_PURPLE'],
#   'next_express_stations': []},
#  'Surabaya': {'lines': {'AQUA'},
#   'next_local_stations': ['Jakarta_AQUA', 'Bali_AQUA'],
#   'next_express_stations': ['Jakarta_AQUA', 'Bali_AQUA']},
#  'Port-au-Prince': {'lines': {'BRONZE', 'PURPLE'},
#   'next_local_stations': ['Kingston_PURPLE',
#    'Santo Domingo_PURPLE',
#    'Santo Domingo_BRONZE',
#    'Kingston_BRONZE'],
#   'next_express_stations': ['Kingston_PURPLE',
#    'Santo Domingo_PURPLE',
#    'Santo Domingo_BRONZE',
#    'Kingston_BRONZE']},
#  'Santiago': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['Buenos Aires_ORANGE',
#    'La Paz_ORANGE',
#    'Buenos Aires_BRONZE'],
#   'next_express_stations': ['Buenos Aires_ORANGE',
#    'La Paz_ORANGE',
#    'Buenos Aires_BRONZE']},
#  'London': {'lines': {'AQUA', 'BRONZE', 'DARKGREEN', 'SILVER'},
#   'next_local_stations': ['Dublin_BRONZE',
#    'Paris_BRONZE',
#    'Brussels_BRONZE',
#    'Glasgow_AQUA',
#    'Paris_AQUA',
#    'Madrid_SILVER',
#    'Barcelona_DARKGREEN',
#    'Amsterdam_DARKGREEN'],
#   'next_express_stations': ['Boston_BRONZE',
#    'Paris_BRONZE',
#    'Brussels_BRONZE',
#    'Paris_AQUA',
#    'Madrid_SILVER',
#    'Barcelona_DARKGREEN',
#    'Amsterdam_DARKGREEN']},
#  'Macau': {'lines': {'AQUA', 'RED'},
#   'next_local_stations': ['Hong Kong_RED',
#    'Sanya_RED',
#    'Hong Kong_AQUA',
#    'Hanoi_AQUA'],
#   'next_express_stations': ['Hong Kong_RED', 'Hong Kong_AQUA', 'Hanoi_AQUA']},
#  'Tripoli': {'lines': {'SILVER'},
#   'next_local_stations': ['Tunis_SILVER', 'Alexandria_SILVER'],
#   'next_express_stations': ['Tunis_SILVER', 'Alexandria_SILVER']},
#  'Khartoum': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Asmara_LIGHTGREEN', 'Cairo_LIGHTGREEN'],
#   'next_express_stations': ['Addis Ababa_LIGHTGREEN', 'Cairo_LIGHTGREEN']},
#  'Sofia': {'lines': {'BRONZE'},
#   'next_local_stations': ['Belgrade_BRONZE', 'Istanbul_BRONZE'],
#   'next_express_stations': []},
#  'Bangalore': {'lines': {'BLUE', 'SILVER'},
#   'next_local_stations': ['Pune_SILVER',
#    'Colombo_SILVER',
#    'Hyderabad_BLUE',
#    'Chennai_BLUE'],
#   'next_express_stations': ['Pune_SILVER',
#    'Medan_SILVER',
#    'Hyderabad_BLUE',
#    'Chennai_BLUE']},
#  'Bishkek': {'lines': {'AQUA'},
#   'next_local_stations': ['Tashkent_AQUA', 'Almaty_AQUA'],
#   'next_express_stations': []},
#  'Kingston': {'lines': {'BRONZE', 'PURPLE'},
#   'next_local_stations': ['Belize City_PURPLE',
#    'Port-au-Prince_PURPLE',
#    'Port-au-Prince_BRONZE',
#    'Havana_BRONZE'],
#   'next_express_stations': ['Guatemala City_PURPLE',
#    'Port-au-Prince_PURPLE',
#    'Port-au-Prince_BRONZE',
#    'Havana_BRONZE']},
#  'Shanghai': {'lines': {'AQUA', 'DARKGREEN', 'NAVY', 'RED'},
#   'next_local_stations': ['Jinan_RED',
#    'Hangzhou_RED',
#    'Tianjin_AQUA',
#    'Hangzhou_AQUA',
#    'Nanjing_NAVY',
#    'Seoul_NAVY',
#    'Taipei_DARKGREEN',
#    'Seoul_DARKGREEN'],
#   'next_express_stations': ['Jinan_RED',
#    'Hangzhou_RED',
#    'Tianjin_AQUA',
#    'Hangzhou_AQUA',
#    'Nanjing_NAVY',
#    'Seoul_NAVY',
#    'Taipei_DARKGREEN',
#    'Seoul_DARKGREEN']},
#  'Kolkata': {'lines': {'LILAC'},
#   'next_local_stations': ['Dhaka_LILAC', 'Hyderabad_LILAC'],
#   'next_express_stations': ['Dhaka_LILAC', 'Hyderabad_LILAC']},
#  'Perth': {'lines': {'AQUA'},
#   'next_local_stations': ['Bali_AQUA', 'Melbourne_AQUA'],
#   'next_express_stations': []},
#  'Brasilia': {'lines': {'BRONZE'},
#   'next_local_stations': ['Belo Horizonte_BRONZE', 'Cayenne_BRONZE'],
#   'next_express_stations': ['Belo Horizonte_BRONZE', 'Port of Spain_BRONZE']},
#  'Manila': {'lines': {'LIGHTGREEN', 'ORANGE', 'SILVER'},
#   'next_local_stations': ['Hong Kong_ORANGE',
#    'Davao_ORANGE',
#    'Bandar Seri Begawan_SILVER',
#    'Taipei_SILVER',
#    'Phnom Penh_LIGHTGREEN'],
#   'next_express_stations': ['Hong Kong_ORANGE',
#    'Dili_ORANGE',
#    'Singapore_SILVER',
#    'Taipei_SILVER',
#    'Bangkok_LIGHTGREEN']},
#  'Monterrey': {'lines': {'PURPLE'},
#   'next_local_stations': ['Houston_PURPLE', 'Mexico City_PURPLE'],
#   'next_express_stations': ['Houston_PURPLE', 'Mexico City_PURPLE']},
#  'Taipei': {'lines': {'AQUA', 'DARKGREEN', 'RED', 'SILVER'},
#   'next_local_stations': ['Hangzhou_RED',
#    'Hong Kong_RED',
#    'Hangzhou_AQUA',
#    'Hong Kong_AQUA',
#    'Manila_SILVER',
#    'Seoul_SILVER',
#    'Hong Kong_DARKGREEN',
#    'Shanghai_DARKGREEN'],
#   'next_express_stations': ['Hangzhou_RED',
#    'Hong Kong_RED',
#    'Hangzhou_AQUA',
#    'Hong Kong_AQUA',
#    'Manila_SILVER',
#    'Seoul_SILVER',
#    'Hong Kong_DARKGREEN',
#    'Shanghai_DARKGREEN']},
#  'Bucharest': {'lines': {'LILAC'},
#   'next_local_stations': ['Istanbul_LILAC', 'Chisinau_LILAC'],
#   'next_express_stations': []},
#  'Bogota': {'lines': {'ORANGE', 'RED'},
#   'next_local_stations': ['Quito_ORANGE',
#    'Medellin_ORANGE',
#    'Caracas_RED',
#    'Quito_RED'],
#   'next_express_stations': ['Quito_ORANGE',
#    'Medellin_ORANGE',
#    'Caracas_RED',
#    'Quito_RED']},
#  'Cotonou': {'lines': {'BRONZE'},
#   'next_local_stations': ['Lome_BRONZE', 'Lagos_BRONZE'],
#   'next_express_stations': []},
#  'Oslo': {'lines': {'RED'},
#   'next_local_stations': ['Copenhagen_RED', 'Stockholm_RED'],
#   'next_express_stations': []},
#  'Kinshasa': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Brazzaville_LIGHTGREEN', 'Bujumbura_LIGHTGREEN'],
#   'next_express_stations': ['Luanda_LIGHTGREEN', 'Kampala_LIGHTGREEN']},
#  'Brisbane': {'lines': {'ORANGE'},
#   'next_local_stations': ['Port Moresby_ORANGE', 'Sydney_ORANGE'],
#   'next_express_stations': []},
#  'Kyiv': {'lines': {'DARKGREEN', 'LILAC'},
#   'next_local_stations': ['Chisinau_LILAC',
#    'Minsk_LILAC',
#    'Warsaw_DARKGREEN',
#    'Sevastopol_DARKGREEN'],
#   'next_express_stations': ['Istanbul_LILAC',
#    'Helsinki_LILAC',
#    'Berlin_DARKGREEN',
#    'Moscow_DARKGREEN']},
#  'Dar es Salaam': {'lines': {'BLUE'},
#   'next_local_stations': ['Lilongwe_BLUE', 'Mombasa_BLUE', 'Moroni_BLUE'],
#   'next_express_stations': ['Johannesburg_BLUE', 'Nairobi_BLUE']},
#  'Chongqing': {'lines': {'NAVY'},
#   'next_local_stations': ['Chengdu_NAVY', 'Wuhan_NAVY'],
#   'next_express_stations': ['Chengdu_NAVY', 'Wuhan_NAVY']},
#  'Casablanca': {'lines': {'BRONZE', 'SILVER'},
#   'next_local_stations': ['Barcelona_BRONZE',
#    'Laayoune_BRONZE',
#    'Madrid_SILVER',
#    'Algiers_SILVER'],
#   'next_express_stations': ['Barcelona_BRONZE',
#    'Dakar_BRONZE',
#    'Bamako_BRONZE',
#    'Madrid_SILVER',
#    'Algiers_SILVER']},
#  'Lima': {'lines': {'ORANGE', 'RED'},
#   'next_local_stations': ['La Paz_ORANGE',
#    'Quito_ORANGE',
#    'Quito_RED',
#    'La Paz_RED'],
#   'next_express_stations': ['La Paz_ORANGE',
#    'Quito_ORANGE',
#    'Quito_RED',
#    'La Paz_RED']},
#  'Urumqi': {'lines': {'AQUA'},
#   'next_local_stations': ['Almaty_AQUA', "Xi'an_AQUA"],
#   'next_express_stations': ['Tashkent_AQUA', "Xi'an_AQUA"]},
#  'Delhi': {'lines': {'BLUE', 'LIGHTGREEN', 'NAVY'},
#   'next_local_stations': ['Mumbai_NAVY',
#    'Kathmandu_NAVY',
#    'Lahore_LIGHTGREEN',
#    'Lucknow_LIGHTGREEN',
#    'Lahore_BLUE',
#    'Nagpur_BLUE'],
#   'next_express_stations': ['Mumbai_NAVY',
#    'Chengdu_NAVY',
#    'Lahore_LIGHTGREEN',
#    'Lucknow_LIGHTGREEN',
#    'Lahore_BLUE',
#    'Nagpur_BLUE']},
#  'Phoenix': {'lines': {'ORANGE'},
#   'next_local_stations': ['Los Angeles_ORANGE', 'Dallas_ORANGE'],
#   'next_express_stations': ['Los Angeles_ORANGE', 'Dallas_ORANGE']},
#  'Lucknow': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Delhi_LIGHTGREEN', 'Dhaka_LIGHTGREEN'],
#   'next_express_stations': ['Delhi_LIGHTGREEN', 'Dhaka_LIGHTGREEN']},
#  'Banjul': {'lines': {'BRONZE'},
#   'next_local_stations': ['Dakar_BRONZE', 'Bissau_BRONZE'],
#   'next_express_stations': []},
#  'Bujumbura': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Kinshasa_LIGHTGREEN', 'Kigali_LIGHTGREEN'],
#   'next_express_stations': []},
#  'Bissau': {'lines': {'BRONZE'},
#   'next_local_stations': ['Banjul_BRONZE', 'Conakry_BRONZE'],
#   'next_express_stations': []},
#  'Guadalajara': {'lines': {'ORANGE'},
#   'next_local_stations': ['Mexico City_ORANGE', 'Los Angeles_ORANGE'],
#   'next_express_stations': ['Mexico City_ORANGE', 'Los Angeles_ORANGE']},
#  'Seoul': {'lines': {'AQUA', 'DARKGREEN', 'NAVY', 'SILVER'},
#   'next_local_stations': ['Dalian_AQUA',
#    'Busan_AQUA',
#    'Taipei_SILVER',
#    'Pyongyang_SILVER',
#    'Shanghai_NAVY',
#    'Busan_NAVY',
#    'Shanghai_DARKGREEN',
#    'Tokyo_DARKGREEN',
#    'Beijing_DARKGREEN'],
#   'next_express_stations': ['Dalian_AQUA',
#    'Busan_AQUA',
#    'Taipei_SILVER',
#    'Pyongyang_SILVER',
#    'Shanghai_NAVY',
#    'Busan_NAVY',
#    'Shanghai_DARKGREEN',
#    'Tokyo_DARKGREEN',
#    'Beijing_DARKGREEN']},
#  'Thimphu': {'lines': {'NAVY'},
#   'next_local_stations': ['Kathmandu_NAVY', 'Chengdu_NAVY'],
#   'next_express_stations': []},
#  'Jerusalem': {'lines': {'LIGHTGREEN', 'SILVER'},
#   'next_local_stations': ['Cairo_SILVER',
#    'Amman_SILVER',
#    'Cairo_LIGHTGREEN',
#    'Beirut_LIGHTGREEN'],
#   'next_express_stations': ['Cairo_SILVER',
#    'Amman_SILVER',
#    'Cairo_LIGHTGREEN',
#    'Beirut_LIGHTGREEN']},
#  'Montreal': {'lines': {'PURPLE'},
#   'next_local_stations': ['Ottawa_PURPLE', 'New York City_PURPLE'],
#   'next_express_stations': ['Toronto_PURPLE', 'New York City_PURPLE']},
#  'Freetown': {'lines': {'BRONZE'},
#   'next_local_stations': ['Conakry_BRONZE', 'Monrovia_BRONZE'],
#   'next_express_stations': []},
#  'Pyongyang': {'lines': {'SILVER'},
#   'next_local_stations': ['Seoul_SILVER', 'Shenyang_SILVER'],
#   'next_express_stations': ['Seoul_SILVER', 'Shenyang_SILVER']},
#  'Honolulu': {'lines': {'DARKGREEN'},
#   'next_local_stations': ['Tokyo_DARKGREEN', 'Los Angeles_DARKGREEN'],
#   'next_express_stations': []},
#  'Belgrade': {'lines': {'BRONZE'},
#   'next_local_stations': ['Budapest_BRONZE', 'Sofia_BRONZE'],
#   'next_express_stations': []},
#  'Managua': {'lines': {'ORANGE'},
#   'next_local_stations': ['San Jose_ORANGE', 'Tegucigalpa_ORANGE'],
#   'next_express_stations': []},
#  'Ankara': {'lines': {'AQUA', 'BRONZE'},
#   'next_local_stations': ['Istanbul_BRONZE',
#    'Beirut_BRONZE',
#    'Istanbul_AQUA',
#    'Yerevan_AQUA'],
#   'next_express_stations': ['Istanbul_BRONZE',
#    'Beirut_BRONZE',
#    'Istanbul_AQUA',
#    'Baku_AQUA']},
#  'Addis Ababa': {'lines': {'BLUE', 'LIGHTGREEN'},
#   'next_local_stations': ['Mogadishu_LIGHTGREEN',
#    'Asmara_LIGHTGREEN',
#    'Nairobi_BLUE',
#    'Djibouti_BLUE'],
#   'next_express_stations': ['Mogadishu_LIGHTGREEN',
#    'Khartoum_LIGHTGREEN',
#    'Nairobi_BLUE',
#    'Sanaa_BLUE']},
#  'Wuhan': {'lines': {'NAVY', 'ORANGE'},
#   'next_local_stations': ['Beijing_ORANGE',
#    'Guangzhou_ORANGE',
#    'Chongqing_NAVY',
#    'Nanjing_NAVY'],
#   'next_express_stations': ['Beijing_ORANGE',
#    'Guangzhou_ORANGE',
#    'Chongqing_NAVY',
#    'Nanjing_NAVY']},
#  'Hong Kong': {'lines': {'AQUA', 'DARKGREEN', 'ORANGE', 'RED'},
#   'next_local_stations': ['Shenzhen_ORANGE',
#    'Manila_ORANGE',
#    'Taipei_RED',
#    'Macau_RED',
#    'Taipei_AQUA',
#    'Macau_AQUA',
#    'Taipei_DARKGREEN'],
#   'next_express_stations': ['Shenzhen_ORANGE',
#    'Manila_ORANGE',
#    'Taipei_RED',
#    'Macau_RED',
#    'Taipei_AQUA',
#    'Macau_AQUA',
#    'Taipei_DARKGREEN']},
#  'Cayenne': {'lines': {'BRONZE'},
#   'next_local_stations': ['Brasilia_BRONZE', 'Paramaribo_BRONZE'],
#   'next_express_stations': []},
#  'Barcelona': {'lines': {'BRONZE', 'DARKGREEN'},
#   'next_local_stations': ['Paris_BRONZE',
#    'Casablanca_BRONZE',
#    'Madrid_DARKGREEN',
#    'London_DARKGREEN',
#    'Milan_DARKGREEN'],
#   'next_express_stations': ['Paris_BRONZE',
#    'Casablanca_BRONZE',
#    'Madrid_DARKGREEN',
#    'London_DARKGREEN',
#    'Milan_DARKGREEN']},
#  'Guangzhou': {'lines': {'ORANGE'},
#   'next_local_stations': ['Wuhan_ORANGE', 'Shenzhen_ORANGE'],
#   'next_express_stations': ['Wuhan_ORANGE', 'Shenzhen_ORANGE']},
#  'Kuala Lumpur': {'lines': {'AQUA', 'SILVER'},
#   'next_local_stations': ['Phuket_AQUA',
#    'Singapore_AQUA',
#    'Medan_SILVER',
#    'Singapore_SILVER'],
#   'next_express_stations': ['Bangkok_AQUA',
#    'Singapore_AQUA',
#    'Medan_SILVER',
#    'Singapore_SILVER']},
#  'Ashgabat': {'lines': {'AQUA'},
#   'next_local_stations': ['Tehran_AQUA', 'Dushanbe_AQUA'],
#   'next_express_stations': []},
#  'Port of Spain': {'lines': {'BRONZE', 'PURPLE'},
#   'next_local_stations': ['Bridgetown_PURPLE',
#    'Georgetown_BRONZE',
#    'Caracas_BRONZE'],
#   'next_express_stations': ['Santo Domingo_PURPLE',
#    'Brasilia_BRONZE',
#    'Caracas_BRONZE']},
#  'Osaka': {'lines': {'AQUA', 'NAVY'},
#   'next_local_stations': ['Fukuoka_AQUA',
#    'Tokyo_AQUA',
#    'Fukuoka_NAVY',
#    'Tokyo_NAVY'],
#   'next_express_stations': ['Fukuoka_AQUA',
#    'Tokyo_AQUA',
#    'Fukuoka_NAVY',
#    'Tokyo_NAVY']},
#  'Surat': {'lines': {'LILAC', 'SILVER'},
#   'next_local_stations': ['Karachi_SILVER',
#    'Ahmadabad_SILVER',
#    'Mumbai_LILAC',
#    'Ahmadabad_LILAC'],
#   'next_express_stations': ['Karachi_SILVER',
#    'Ahmadabad_SILVER',
#    'Mumbai_LILAC',
#    'Ahmadabad_LILAC']},
#  'Mashhad': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Tehran_LIGHTGREEN', 'Kabul_LIGHTGREEN'],
#   'next_express_stations': ['Tehran_LIGHTGREEN', 'Kabul_LIGHTGREEN']},
#  'Chennai': {'lines': {'BLUE'},
#   'next_local_stations': ['Bangalore_BLUE'],
#   'next_express_stations': ['Bangalore_BLUE']},
#  'Bridgetown': {'lines': {'PURPLE'},
#   'next_local_stations': ['Fort-de-France_PURPLE', 'Port of Spain_PURPLE'],
#   'next_express_stations': []},
#  'Salvador': {'lines': {'RED'},
#   'next_local_stations': ['Rio de Janeiro_RED', 'Fortaleza_RED'],
#   'next_express_stations': ['Rio de Janeiro_RED', 'Fortaleza_RED']},
#  'Singapore': {'lines': {'AQUA', 'LIGHTGREEN', 'SILVER'},
#   'next_local_stations': ['Kuala Lumpur_AQUA',
#    'Jakarta_AQUA',
#    'Kuala Lumpur_SILVER',
#    'Bandar Seri Begawan_SILVER',
#    'Ho Chi Minh City_LIGHTGREEN',
#    'Jakarta_LIGHTGREEN'],
#   'next_express_stations': ['Kuala Lumpur_AQUA',
#    'Jakarta_AQUA',
#    'Kuala Lumpur_SILVER',
#    'Manila_SILVER',
#    'Ho Chi Minh City_LIGHTGREEN',
#    'Jakarta_LIGHTGREEN']},
#  'Riga': {'lines': {'LILAC'},
#   'next_local_stations': ['Vilnius_LILAC', 'Tallinn_LILAC'],
#   'next_express_stations': []},
#  'Karachi': {'lines': {'BLUE', 'LILAC', 'SILVER'},
#   'next_local_stations': ['Muscat_SILVER',
#    'Surat_SILVER',
#    'Tehran_BLUE',
#    'Lahore_BLUE',
#    'Ahmadabad_LILAC',
#    'Muscat_LILAC'],
#   'next_express_stations': ['Muscat_SILVER',
#    'Surat_SILVER',
#    'Tehran_BLUE',
#    'Lahore_BLUE',
#    'Ahmadabad_LILAC',
#    'Muscat_LILAC']},
#  'Lusaka': {'lines': {'BRONZE'},
#   'next_local_stations': ['Lubumbashi_BRONZE', 'Gaborone_BRONZE'],
#   'next_express_stations': []},
#  'Abu Dhabi': {'lines': {'LILAC', 'SILVER'},
#   'next_local_stations': ['Riyadh_SILVER',
#    'Dubai_SILVER',
#    'Dubai_LILAC',
#    'Riyadh_LILAC'],
#   'next_express_stations': ['Riyadh_SILVER',
#    'Dubai_SILVER',
#    'Dubai_LILAC',
#    'Riyadh_LILAC']},
#  'Accra': {'lines': {'BRONZE', 'NAVY'},
#   'next_local_stations': ['Abidjan_BRONZE',
#    'Lome_BRONZE',
#    'Ouagadougou_NAVY',
#    'Lagos_NAVY'],
#   'next_express_stations': ['Abidjan_BRONZE',
#    'Lagos_BRONZE',
#    'Ouagadougou_NAVY',
#    'Lagos_NAVY']},
#  'Almaty': {'lines': {'AQUA'},
#   'next_local_stations': ['Bishkek_AQUA', 'Urumqi_AQUA'],
#   'next_express_stations': []},
#  'Fukuoka': {'lines': {'AQUA', 'NAVY'},
#   'next_local_stations': ['Busan_AQUA',
#    'Osaka_AQUA',
#    'Busan_NAVY',
#    'Osaka_NAVY'],
#   'next_express_stations': ['Busan_AQUA',
#    'Osaka_AQUA',
#    'Busan_NAVY',
#    'Osaka_NAVY']},
#  'Baghdad': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Damascus_LIGHTGREEN', 'Tehran_LIGHTGREEN'],
#   'next_express_stations': ['Damascus_LIGHTGREEN', 'Tehran_LIGHTGREEN']},
#  "N'Djamena": {'lines': {'BRONZE'},
#   'next_local_stations': ['Kano_BRONZE', 'Bangui_BRONZE'],
#   'next_express_stations': []},
#  'Rio de Janeiro': {'lines': {'BRONZE', 'ORANGE', 'RED'},
#   'next_local_stations': ['Sao Paulo_ORANGE',
#    'Sao Paulo_RED',
#    'Salvador_RED',
#    'Sao Paulo_BRONZE',
#    'Belo Horizonte_BRONZE'],
#   'next_express_stations': ['Sao Paulo_ORANGE',
#    'Sao Paulo_RED',
#    'Salvador_RED',
#    'Sao Paulo_BRONZE',
#    'Belo Horizonte_BRONZE']},
#  'Kazan': {'lines': {'RED'},
#   'next_local_stations': ['Moscow_RED', 'Yekaterinburg_RED'],
#   'next_express_stations': []},
#  'Beirut': {'lines': {'BRONZE', 'LIGHTGREEN'},
#   'next_local_stations': ['Ankara_BRONZE',
#    'Amman_BRONZE',
#    'Jerusalem_LIGHTGREEN',
#    'Damascus_LIGHTGREEN'],
#   'next_express_stations': ['Ankara_BRONZE',
#    'Amman_BRONZE',
#    'Jerusalem_LIGHTGREEN',
#    'Damascus_LIGHTGREEN']},
#  'Libreville': {'lines': {'BRONZE'},
#   'next_local_stations': ['Bata_BRONZE', 'Luanda_BRONZE'],
#   'next_express_stations': []},
#  'Belize City': {'lines': {'PURPLE'},
#   'next_local_stations': ['Guatemala City_PURPLE', 'Kingston_PURPLE'],
#   'next_express_stations': []},
#  'Port Louis': {'lines': {'BLUE'},
#   'next_local_stations': ['Saint-Denis_BLUE'],
#   'next_express_stations': []},
#  'Santo Domingo': {'lines': {'BRONZE', 'PURPLE'},
#   'next_local_stations': ['Port-au-Prince_PURPLE',
#    'San Juan_PURPLE',
#    'Caracas_BRONZE',
#    'Port-au-Prince_BRONZE'],
#   'next_express_stations': ['Port-au-Prince_PURPLE',
#    'Port of Spain_PURPLE',
#    'Caracas_BRONZE',
#    'Port-au-Prince_BRONZE']},
#  'Saint-Denis': {'lines': {'BLUE'},
#   'next_local_stations': ['Antananarivo_BLUE', 'Port Louis_BLUE'],
#   'next_express_stations': []},
#  'Dili': {'lines': {'LIGHTGREEN', 'ORANGE'},
#   'next_local_stations': ['Davao_ORANGE',
#    'Port Moresby_ORANGE',
#    'Bali_LIGHTGREEN'],
#   'next_express_stations': ['Manila_ORANGE',
#    'Sydney_ORANGE',
#    'Bali_LIGHTGREEN']},
#  'Kuwait City': {'lines': {'BLUE'},
#   'next_local_stations': ['Manama_BLUE', 'Tehran_BLUE'],
#   'next_express_stations': ['Doha_BLUE', 'Tehran_BLUE']},
#  'Algiers': {'lines': {'SILVER'},
#   'next_local_stations': ['Casablanca_SILVER', 'Tunis_SILVER'],
#   'next_express_stations': ['Casablanca_SILVER', 'Tunis_SILVER']},
#  'Bandar Seri Begawan': {'lines': {'SILVER'},
#   'next_local_stations': ['Singapore_SILVER', 'Manila_SILVER'],
#   'next_express_stations': []},
#  'Harare': {'lines': {'BLUE'},
#   'next_local_stations': ['Maputo_BLUE', 'Lilongwe_BLUE'],
#   'next_express_stations': []},
#  'Chisinau': {'lines': {'LILAC'},
#   'next_local_stations': ['Bucharest_LILAC', 'Kyiv_LILAC'],
#   'next_express_stations': []},
#  'Moroni': {'lines': {'BLUE'},
#   'next_local_stations': ['Dar es Salaam_BLUE', 'Antananarivo_BLUE'],
#   'next_express_stations': []},
#  'Muscat': {'lines': {'LILAC', 'SILVER'},
#   'next_local_stations': ['Dubai_SILVER',
#    'Karachi_SILVER',
#    'Karachi_LILAC',
#    'Dubai_LILAC'],
#   'next_express_stations': ['Dubai_SILVER',
#    'Karachi_SILVER',
#    'Karachi_LILAC',
#    'Dubai_LILAC']},
#  'Vienna': {'lines': {'LILAC'},
#   'next_local_stations': ['Zagreb_LILAC', 'Prague_LILAC'],
#   'next_express_stations': ['Zagreb_LILAC', 'Prague_LILAC']},
#  'Glasgow': {'lines': {'AQUA'},
#   'next_local_stations': ['Reykjavik_AQUA', 'London_AQUA'],
#   'next_express_stations': []},
#  'Ouagadougou': {'lines': {'BRONZE', 'NAVY'},
#   'next_local_stations': ['Bamako_BRONZE',
#    'Niamey_BRONZE',
#    'Bamako_NAVY',
#    'Accra_NAVY'],
#   'next_express_stations': ['Bamako_BRONZE',
#    'Kano_BRONZE',
#    'Bamako_NAVY',
#    'Accra_NAVY']},
#  'Stockholm': {'lines': {'RED'},
#   'next_local_stations': ['Oslo_RED', 'Helsinki_RED'],
#   'next_express_stations': []},
#  'Paris': {'lines': {'AQUA', 'BRONZE', 'RED'},
#   'next_local_stations': ['Lyon_RED',
#    'Brussels_RED',
#    'London_BRONZE',
#    'Barcelona_BRONZE',
#    'London_AQUA',
#    'Zurich_AQUA'],
#   'next_express_stations': ['Milan_RED',
#    'Brussels_RED',
#    'London_BRONZE',
#    'Barcelona_BRONZE',
#    'London_AQUA',
#    'Zagreb_AQUA']},
#  'Miami': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['Houston_ORANGE',
#    'Nassau_ORANGE',
#    'Havana_BRONZE',
#    'Atlanta_BRONZE'],
#   'next_express_stations': ['Houston_ORANGE',
#    'Havana_BRONZE',
#    'Atlanta_BRONZE']},
#  'Maputo': {'lines': {'BLUE'},
#   'next_local_stations': ['Mbabane_BLUE', 'Harare_BLUE'],
#   'next_express_stations': []},
#  'Winnipeg': {'lines': {'PURPLE'},
#   'next_local_stations': ['Calgary_PURPLE', 'Toronto_PURPLE'],
#   'next_express_stations': []},
#  'Chittagong': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Dhaka_LIGHTGREEN', 'Mandalay_LIGHTGREEN'],
#   'next_express_stations': ['Dhaka_LIGHTGREEN', 'Yangon_LIGHTGREEN']},
#  "Xi'an": {'lines': {'AQUA', 'DARKGREEN'},
#   'next_local_stations': ['Urumqi_AQUA',
#    'Beijing_AQUA',
#    'Beijing_DARKGREEN',
#    'Chengdu_DARKGREEN'],
#   'next_express_stations': ['Urumqi_AQUA',
#    'Beijing_AQUA',
#    'Beijing_DARKGREEN',
#    'Chengdu_DARKGREEN']},
#  'Minsk': {'lines': {'LILAC'},
#   'next_local_stations': ['Kyiv_LILAC', 'Vilnius_LILAC'],
#   'next_express_stations': []},
#  'Beijing': {'lines': {'AQUA', 'DARKGREEN', 'ORANGE', 'RED'},
#   'next_local_stations': ['Shenyang_ORANGE',
#    'Wuhan_ORANGE',
#    'Ulaanbaatar_RED',
#    'Jinan_RED',
#    "Xi'an_AQUA",
#    'Tianjin_AQUA',
#    'Seoul_DARKGREEN',
#    "Xi'an_DARKGREEN"],
#   'next_express_stations': ['Shenyang_ORANGE',
#    'Wuhan_ORANGE',
#    'Moscow_RED',
#    'Jinan_RED',
#    "Xi'an_AQUA",
#    'Tianjin_AQUA',
#    'Seoul_DARKGREEN',
#    "Xi'an_DARKGREEN"]},
#  'Santa Cruz de la Sierra': {'lines': {'RED'},
#   'next_local_stations': ['La Paz_RED', 'Asuncion_RED'],
#   'next_express_stations': []},
#  'Istanbul': {'lines': {'AQUA', 'BRONZE', 'LILAC'},
#   'next_local_stations': ['Sofia_BRONZE',
#    'Ankara_BRONZE',
#    'Skopje_AQUA',
#    'Ankara_AQUA',
#    'Athens_LILAC',
#    'Bucharest_LILAC'],
#   'next_express_stations': ['Prague_BRONZE',
#    'Ankara_BRONZE',
#    'Zagreb_AQUA',
#    'Ankara_AQUA',
#    'Athens_LILAC',
#    'Kyiv_LILAC']},
#  'La Paz': {'lines': {'ORANGE', 'RED'},
#   'next_local_stations': ['Santiago_ORANGE',
#    'Lima_ORANGE',
#    'Lima_RED',
#    'Santa Cruz de la Sierra_RED'],
#   'next_express_stations': ['Santiago_ORANGE',
#    'Lima_ORANGE',
#    'Lima_RED',
#    'Sao Paulo_RED']},
#  'Tokyo': {'lines': {'AQUA', 'DARKGREEN', 'NAVY', 'RED'},
#   'next_local_stations': ['Sapporo_RED',
#    'Osaka_AQUA',
#    'Osaka_NAVY',
#    'Seoul_DARKGREEN',
#    'Honolulu_DARKGREEN'],
#   'next_express_stations': ['Sapporo_RED',
#    'Osaka_AQUA',
#    'Osaka_NAVY',
#    'Seoul_DARKGREEN',
#    'Los Angeles_DARKGREEN']},
#  'Sarajevo': {'lines': {'AQUA'},
#   'next_local_stations': ['Zagreb_AQUA', 'Tirana_AQUA'],
#   'next_express_stations': []},
#  'Medan': {'lines': {'SILVER'},
#   'next_local_stations': ['Colombo_SILVER', 'Kuala Lumpur_SILVER'],
#   'next_express_stations': ['Bangalore_SILVER', 'Kuala Lumpur_SILVER']},
#  'Khabarovsk': {'lines': {'ORANGE', 'RED'},
#   'next_local_stations': ['Anchorage_ORANGE',
#    'Harbin_ORANGE',
#    'Irkutsk_RED',
#    'Vladivostok_RED'],
#   'next_express_stations': ['Vancouver_ORANGE',
#    'Harbin_ORANGE',
#    'Moscow_RED',
#    'Sapporo_RED']},
#  'Colombo': {'lines': {'SILVER'},
#   'next_local_stations': ['Bangalore_SILVER', 'Medan_SILVER'],
#   'next_express_stations': []},
#  'Bamako': {'lines': {'BRONZE', 'NAVY'},
#   'next_local_stations': ['Nouakchott_BRONZE',
#    'Ouagadougou_BRONZE',
#    'Dakar_NAVY',
#    'Ouagadougou_NAVY'],
#   'next_express_stations': ['Casablanca_BRONZE',
#    'Ouagadougou_BRONZE',
#    'Dakar_NAVY',
#    'Ouagadougou_NAVY']},
#  'Fortaleza': {'lines': {'RED'},
#   'next_local_stations': ['Salvador_RED', 'Lagos_RED'],
#   'next_express_stations': ['Salvador_RED', 'Lagos_RED']},
#  'Mbabane': {'lines': {'BLUE'},
#   'next_local_stations': ['Johannesburg_BLUE', 'Maputo_BLUE'],
#   'next_express_stations': []},
#  'Tashkent': {'lines': {'AQUA'},
#   'next_local_stations': ['Dushanbe_AQUA', 'Bishkek_AQUA'],
#   'next_express_stations': ['Tehran_AQUA', 'Urumqi_AQUA']},
#  'Asuncion': {'lines': {'RED'},
#   'next_local_stations': ['Santa Cruz de la Sierra_RED', 'Sao Paulo_RED'],
#   'next_express_stations': []},
#  'Christchurch': {'lines': {'AQUA'},
#   'next_local_stations': ['Auckland_AQUA'],
#   'next_express_stations': []},
#  'Amsterdam': {'lines': {'DARKGREEN', 'RED'},
#   'next_local_stations': ['Brussels_RED',
#    'Copenhagen_RED',
#    'London_DARKGREEN',
#    'Berlin_DARKGREEN'],
#   'next_express_stations': ['Brussels_RED',
#    'Copenhagen_RED',
#    'London_DARKGREEN',
#    'Berlin_DARKGREEN']},
#  'Lagos': {'lines': {'BRONZE', 'NAVY', 'RED'},
#   'next_local_stations': ['Fortaleza_RED',
#    'Abuja_RED',
#    'Cotonou_BRONZE',
#    'Douala_BRONZE',
#    'Accra_NAVY',
#    'Yaounde_NAVY'],
#   'next_express_stations': ['Fortaleza_RED',
#    'Kano_RED',
#    'Accra_BRONZE',
#    'Luanda_BRONZE',
#    'Accra_NAVY',
#    'Bangui_NAVY']},
#  'Havana': {'lines': {'BRONZE'},
#   'next_local_stations': ['Kingston_BRONZE', 'Miami_BRONZE'],
#   'next_express_stations': ['Kingston_BRONZE', 'Miami_BRONZE']},
#  'Baku': {'lines': {'AQUA'},
#   'next_local_stations': ['Tbilisi_AQUA', 'Tehran_AQUA'],
#   'next_express_stations': ['Ankara_AQUA', 'Tehran_AQUA']},
#  'Vientiane': {'lines': {'AQUA'},
#   'next_local_stations': ['Hanoi_AQUA', 'Bangkok_AQUA'],
#   'next_express_stations': []},
#  'Kabul': {'lines': {'LIGHTGREEN'},
#   'next_local_stations': ['Mashhad_LIGHTGREEN', 'Islamabad_LIGHTGREEN'],
#   'next_express_stations': ['Mashhad_LIGHTGREEN', 'Lahore_LIGHTGREEN']},
#  'Gaborone': {'lines': {'BRONZE'},
#   'next_local_stations': ['Lusaka_BRONZE', 'Johannesburg_BRONZE'],
#   'next_express_stations': []},
#  'Amman': {'lines': {'BRONZE', 'SILVER'},
#   'next_local_stations': ['Beirut_BRONZE',
#    'Doha_BRONZE',
#    'Jerusalem_SILVER',
#    'Riyadh_SILVER'],
#   'next_express_stations': ['Beirut_BRONZE',
#    'Doha_BRONZE',
#    'Jerusalem_SILVER',
#    'Riyadh_SILVER']},
#  'Djibouti': {'lines': {'BLUE'},
#   'next_local_stations': ['Addis Ababa_BLUE', 'Sanaa_BLUE'],
#   'next_express_stations': []},
#  'San Jose': {'lines': {'ORANGE'},
#   'next_local_stations': ['Panama City_ORANGE', 'Managua_ORANGE'],
#   'next_express_stations': []},
#  'Nanjing': {'lines': {'NAVY'},
#   'next_local_stations': ['Wuhan_NAVY', 'Shanghai_NAVY'],
#   'next_express_stations': ['Wuhan_NAVY', 'Shanghai_NAVY']},
#  'Vladivostok': {'lines': {'RED'},
#   'next_local_stations': ['Khabarovsk_RED', 'Sapporo_RED'],
#   'next_express_stations': []},
#  'Boston': {'lines': {'BRONZE', 'ORANGE'},
#   'next_local_stations': ['New York City_ORANGE',
#    'New York City_BRONZE',
#    'Dublin_BRONZE'],
#   'next_express_stations': ['New York City_ORANGE',
#    'New York City_BRONZE',
#    'London_BRONZE']}}

# %%
line_dict
# Out:
# {'ORANGE': ['Rio de Janeiro',
#   'Sao Paulo',
#   'Montevideo',
#   'Buenos Aires',
#   'Santiago',
#   'La Paz',
#   'Lima',
#   'Quito',
#   'Bogota',
#   'Medellin',
#   'Panama City',
#   'San Jose',
#   'Managua',
#   'Tegucigalpa',
#   'San Salvador',
#   'Guatemala City',
#   'Mexico City',
#   'Guadalajara',
#   'Los Angeles',
#   'San Francisco',
#   'Seattle',
#   'Vancouver',
#   'Anchorage',
#   'Khabarovsk',
#   'Harbin',
#   'Shenyang',
#   'Beijing',
#   'Wuhan',
#   'Guangzhou',
#   'Shenzhen',
#   'Hong Kong',
#   'Manila',
#   'Davao',
#   'Dili',
#   'Port Moresby',
#   'Brisbane',
#   'Sydney',
#   'Melbourne'],
#  'Los Angeles_ORANGE_L': ['Phoenix', 'Dallas', 'Houston', 'Miami', 'Nassau'],
#  'Seattle_ORANGE_L': ['Chicago', 'Washington D.C.', 'New York City', 'Boston'],
#  'Port Moresby_ORANGE_R': ['Honiara', 'Noumea', 'Suva'],
#  'RED': ['Caracas',
#   'Bogota',
#   'Quito',
#   'Lima',
#   'La Paz',
#   'Santa Cruz de la Sierra',
#   'Asuncion',
#   'Sao Paulo',
#   'Rio de Janeiro',
#   'Salvador',
#   'Fortaleza',
#   'Lagos',
#   'Abuja',
#   'Kano',
#   'Tunis',
#   'Rome',
#   'Milan',
#   'Monaco',
#   'Lyon',
#   'Paris',
#   'Brussels',
#   'Amsterdam',
#   'Copenhagen',
#   'Oslo',
#   'Stockholm',
#   'Helsinki',
#   'Saint Petersburg',
#   'Moscow',
#   'Kazan',
#   'Yekaterinburg',
#   'Novosibirsk',
#   'Krasnoyarsk',
#   'Irkutsk',
#   'Ulaanbaatar',
#   'Beijing',
#   'Jinan',
#   'Shanghai',
#   'Hangzhou',
#   'Taipei',
#   'Hong Kong',
#   'Macau',
#   'Sanya'],
#  'Irkutsk_RED_R': ['Khabarovsk', 'Vladivostok', 'Sapporo', 'Tokyo'],
#  'PURPLE': ['Vancouver',
#   'Calgary',
#   'Winnipeg',
#   'Toronto',
#   'Ottawa',
#   'Montreal',
#   'New York City',
#   'Atlanta',
#   'Houston',
#   'Monterrey',
#   'Mexico City',
#   'Guatemala City',
#   'Belize City',
#   'Kingston',
#   'Port-au-Prince',
#   'Santo Domingo',
#   'San Juan',
#   'Basse-Terre',
#   'Fort-de-France',
#   'Bridgetown',
#   'Port of Spain'],
#  'BRONZE': ['Santiago',
#   'Buenos Aires',
#   'Montevideo',
#   'Sao Paulo',
#   'Rio de Janeiro',
#   'Belo Horizonte',
#   'Brasilia',
#   'Cayenne',
#   'Paramaribo',
#   'Georgetown',
#   'Port of Spain',
#   'Caracas',
#   'Santo Domingo',
#   'Port-au-Prince',
#   'Kingston',
#   'Havana',
#   'Miami',
#   'Atlanta',
#   'Washington D.C.',
#   'New York City',
#   'Boston',
#   'Dublin',
#   'London',
#   'Paris',
#   'Barcelona',
#   'Casablanca',
#   'Laayoune',
#   'Nouakchott',
#   'Dakar',
#   'Banjul',
#   'Bissau',
#   'Conakry',
#   'Freetown',
#   'Monrovia',
#   'Abidjan',
#   'Accra',
#   'Lome',
#   'Cotonou',
#   'Lagos',
#   'Douala',
#   'Bata',
#   'Libreville',
#   'Luanda',
#   'Lubumbashi',
#   'Lusaka',
#   'Gaborone',
#   'Johannesburg'],
#  'London_BRONZE_R': ['Brussels',
#   'Frankfurt',
#   'Prague',
#   'Bratislava',
#   'Budapest',
#   'Belgrade',
#   'Sofia',
#   'Istanbul',
#   'Ankara',
#   'Beirut',
#   'Amman',
#   'Doha',
#   'Dubai'],
#  'Nouakchott_BRONZE_R': ['Bamako',
#   'Ouagadougou',
#   'Niamey',
#   'Kano',
#   "N'Djamena",
#   'Bangui',
#   'Juba',
#   'Kampala',
#   'Nairobi'],
#  'AQUA': ['Reykjavik',
#   'Glasgow',
#   'London',
#   'Paris',
#   'Zurich',
#   'Ljubljana',
#   'Zagreb',
#   'Sarajevo',
#   'Tirana',
#   'Skopje',
#   'Istanbul',
#   'Ankara',
#   'Yerevan',
#   'Tbilisi',
#   'Baku',
#   'Tehran',
#   'Ashgabat',
#   'Dushanbe',
#   'Tashkent',
#   'Bishkek',
#   'Almaty',
#   'Urumqi',
#   "Xi'an",
#   'Beijing',
#   'Tianjin',
#   'Shanghai',
#   'Hangzhou',
#   'Taipei',
#   'Hong Kong',
#   'Macau',
#   'Hanoi',
#   'Vientiane',
#   'Bangkok',
#   'Phuket',
#   'Kuala Lumpur',
#   'Singapore',
#   'Jakarta',
#   'Surabaya',
#   'Bali',
#   'Perth',
#   'Melbourne',
#   'Sydney',
#   'Auckland',
#   'Christchurch'],
#  'Tianjin_AQUA_R': ['Dalian', 'Seoul', 'Busan', 'Fukuoka', 'Osaka', 'Tokyo'],
#  'SILVER': ['London',
#   'Madrid',
#   'Casablanca',
#   'Algiers',
#   'Tunis',
#   'Tripoli',
#   'Alexandria',
#   'Cairo',
#   'Jerusalem',
#   'Amman',
#   'Riyadh',
#   'Abu Dhabi',
#   'Dubai',
#   'Muscat',
#   'Karachi',
#   'Surat',
#   'Ahmadabad',
#   'Mumbai',
#   'Pune',
#   'Bangalore',
#   'Colombo',
#   'Medan',
#   'Kuala Lumpur',
#   'Singapore',
#   'Bandar Seri Begawan',
#   'Manila',
#   'Taipei',
#   'Seoul',
#   'Pyongyang',
#   'Shenyang'],
#  'NAVY': ['Dakar',
#   'Bamako',
#   'Ouagadougou',
#   'Accra',
#   'Lagos',
#   'Yaounde',
#   'Bangui',
#   'Mwanza',
#   'Nairobi',
#   'Mogadishu',
#   'Male',
#   'Mumbai',
#   'Delhi',
#   'Kathmandu',
#   'Thimphu',
#   'Chengdu',
#   'Chongqing',
#   'Wuhan',
#   'Nanjing',
#   'Shanghai',
#   'Seoul',
#   'Busan',
#   'Fukuoka',
#   'Osaka',
#   'Tokyo'],
#  'LIGHTGREEN': ['Cape Town',
#   'Windhoek',
#   'Luanda',
#   'Brazzaville',
#   'Kinshasa',
#   'Bujumbura',
#   'Kigali',
#   'Kampala',
#   'Nairobi',
#   'Mogadishu',
#   'Addis Ababa',
#   'Asmara',
#   'Khartoum',
#   'Cairo',
#   'Jerusalem',
#   'Beirut',
#   'Damascus',
#   'Baghdad',
#   'Tehran',
#   'Mashhad',
#   'Kabul',
#   'Islamabad',
#   'Lahore',
#   'Delhi',
#   'Lucknow',
#   'Dhaka',
#   'Chittagong',
#   'Mandalay',
#   'Yangon',
#   'Bangkok',
#   'Phnom Penh',
#   'Ho Chi Minh City',
#   'Singapore',
#   'Jakarta',
#   'Bali',
#   'Dili'],
#  'Phnom Penh_LIGHTGREEN_R': ['Manila'],
#  'BLUE': ['Cape Town',
#   'Maseru',
#   'Johannesburg',
#   'Mbabane',
#   'Maputo',
#   'Harare',
#   'Lilongwe',
#   'Dar es Salaam',
#   'Mombasa',
#   'Nairobi',
#   'Addis Ababa',
#   'Djibouti',
#   'Sanaa',
#   'Dubai',
#   'Doha',
#   'Manama',
#   'Kuwait City',
#   'Tehran',
#   'Karachi',
#   'Lahore',
#   'Delhi',
#   'Nagpur',
#   'Hyderabad',
#   'Bangalore',
#   'Chennai'],
#  'Dar es Salaam_BLUE_L': ['Moroni',
#   'Antananarivo',
#   'Saint-Denis',
#   'Port Louis'],
#  'LILAC': ['Bangkok',
#   'Yangon',
#   'Dhaka',
#   'Kolkata',
#   'Hyderabad',
#   'Mumbai',
#   'Surat',
#   'Ahmadabad',
#   'Karachi',
#   'Muscat',
#   'Dubai',
#   'Abu Dhabi',
#   'Riyadh',
#   'Jeddah',
#   'Cairo',
#   'Athens',
#   'Istanbul',
#   'Bucharest',
#   'Chisinau',
#   'Kyiv',
#   'Minsk',
#   'Vilnius',
#   'Riga',
#   'Tallinn',
#   'Helsinki',
#   'Saint Petersburg',
#   'Moscow'],
#  'Athens_LILAC_R': ['Rome',
#   'Zagreb',
#   'Vienna',
#   'Prague',
#   'Berlin',
#   'Copenhagen'],
#  'DARKGREEN': ['Hong Kong',
#   'Taipei',
#   'Shanghai',
#   'Seoul',
#   'Tokyo',
#   'Honolulu',
#   'Los Angeles',
#   'Las Vegas',
#   'Denver',
#   'Chicago',
#   'Toronto',
#   'New York City',
#   'Lisbon',
#   'Madrid',
#   'Barcelona',
#   'London',
#   'Amsterdam',
#   'Berlin',
#   'Warsaw',
#   'Kyiv',
#   'Sevastopol',
#   'Moscow'],
#  'Barcelona_DARKGREEN_R': ['Milan', 'Rome', 'Athens', 'Cairo'],
#  'Seoul_DARKGREEN_L': ['Beijing', "Xi'an", 'Chengdu', 'Bangkok']}
